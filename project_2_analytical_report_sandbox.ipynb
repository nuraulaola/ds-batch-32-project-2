# %% [markdown]
# # Analytical Report Netflix Movies

# %% [markdown]
# Netflix adalah aplikasi yang terus berkembang pesat dalam hal popularitas, program acara, dan kontennya.
#
# Ibaratkan kita adalah seorang data scientist dari suatu media yang membahas tentang dunia perfilman. Anda diminta untuk melakukan analisis terkait dengan film-film yang tersedia di netflix dan dampak yang diberikan dari konten yang tersedia di netflix.
#
# Di sini kita akan belajar membuat analytical report sesuai dengan objektif analisis film-film yang tersedia di netflix dan dampak yang diberikan dari konten yang tersedia di netflix. Objektif ini kita persempit ke:
#
# - Film apakah yang paling populer, skor IMDb tertinggi, dan menguntungkan
# - Film dengan genre apa yang paling banyak di netflix
# - Siapakah target market netflix
# - Apakah ada negara yang memiliki skor IMDb tertinggi melebihi Hollywood/Amerika
# - Kapan konten netflix paling banyak dirilis
# - Berapakah durasi umumnya konten film di netflix
# - Seperti apakah outlier kolom finansial pada data
# - Apakah ada hubungan linier antara pendapatan film dengan skor IMDb
#
# Dataset yang digunakan:
# Netflix = https://www.kaggle.com/datasets/shivamb/netflix-shows/download?datasetVersionNumber=5
# IMDb: https://www.kaggle.com/datasets/ashpalsingh1525/imdb-movies-dataset/download?datasetVersionNumber=1
#
# Kedua dataset yg sudah di-download dari url di atas di-import ke google drive masing-masing

# %% [markdown]
# # Mount Google Drive & Import Library

# %%
# Mount google drive

from google.colab import drive
drive.mount('drive')
# Out:
# Mounted at drive

# %%
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import matplotlib # modul visualisasi paling dasar
import matplotlib.pyplot as plt # fungsi untuk membuat visualiasi dari modul matplotlib
import seaborn as sns # modul visualisasi advance
import plotly # modul visualisasi interaktif
import plotly.express as px # fungsi plotly yang lebih sederhana dan lebih cepat
import numpy as np # modul pengolahan data numerik
import warnings # mengatur warning message

# setiap warning non error yang muncul akan dihide
warnings.filterwarnings('ignore')

# %% [markdown]
# # Load Dataset

# %% [markdown]
# ### Netflix Dataset
#
# Load dataset netflix yang sudah tersedia di google drive

# %%
df_netflix=pd.read_csv('drive/My Drive/Dataset/netflix_titles.csv')

# %%
data_netflix = df_netflix
data_netflix.head()
# Out:
#   show_id     type                  title         director  \
# 0      s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1      s2  TV Show          Blood & Water              NaN
# 2      s3  TV Show              Ganglands  Julien Leclercq
# 3      s4  TV Show  Jailbirds New Orleans              NaN
# 4      s5  TV Show           Kota Factory              NaN
#
#                                                 cast        country  \
# 0                                                NaN  United States
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# 2  Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...            NaN
# 3                                                NaN            NaN
# 4  Mayur More, Jitendra Kumar, Ranjan Raj, Alam K...          India
#
#            date_added  release_year rating   duration  \
# 0  September 25, 2021          2020  PG-13     90 min
# 1  September 24, 2021          2021  TV-MA  2 Seasons
# 2  September 24, 2021          2021  TV-MA   1 Season
# 3  September 24, 2021          2021  TV-MA   1 Season
# 4  September 24, 2021          2021  TV-MA  2 Seasons
#
#                                            listed_in  \
# 0                                      Documentaries
# 1    International TV Shows, TV Dramas, TV Mysteries
# 2  Crime TV Shows, International TV Shows, TV Act...
# 3                             Docuseries, Reality TV
# 4  International TV Shows, Romantic TV Shows, TV ...
#
#                                          description
# 0  As her father nears the end of his life, filmm...
# 1  After crossing paths at a party, a Cape Town t...
# 2  To protect his family from a powerful drug lor...
# 3  Feuds, flirtations and toilet talk go down amo...
# 4  In a city of coaching centers known to train I...

# %% [markdown]
# Kita ambil khusus data film saja pada dataset, kemudian kita bersihkan dari whitespace & diubah menjadi lowercase agar lebih rapih dalam pengolahannya

# %%
data_netflix = data_netflix[data_netflix['type'] == 'Movie']

print(data_netflix.shape)

data_netflix['title'] = data_netflix['title'].str.lower()
data_netflix['title'] = data_netflix['title'].str.strip()
data_netflix['title']
# Out:
# (6029, 12)
# 0                   dick johnson is dead
# 6       my little pony: a new generation
# 7                                sankofa
# 9                           the starling
# 12                          je suis karl
#                       ...
# 8699                             zinzana
# 8700                              zodiac
# 8702                          zombieland
# 8703                                zoom
# 8704                              zubaan
# Name: title, Length: 6029, dtype: object

# %% [markdown]
# ### IMDb Dataset
#
# Load dataset IMDb yang sudah tersedia di google drive

# %%
df_imdb=pd.read_csv('drive/My Drive/Dataset/imdb_movies.csv')
data_imdb = df_imdb
data_imdb.head()
# Out:
#                          names       date_x  score  \
# 0                    Creed III  03/02/2023    73.0
# 1     Avatar: The Way of Water  12/15/2022    78.0
# 2  The Super Mario Bros. Movie  04/05/2023    76.0
# 3                      Mummies  01/05/2023    70.0
# 4                    Supercell  03/17/2023    61.0
#
#                                            genre  \
# 0                                  Drama, Action
# 1             Science Fiction, Adventure, Action
# 2  Animation, Adventure, Family, Fantasy, Comedy
# 3  Animation, Comedy, Family, Adventure, Fantasy
# 4                                         Action
#
#                                             overview  \
# 0  After dominating the boxing world, Adonis Cree...
# 1  Set more than a decade after the events of the...
# 2  While working underground to fix a water main,...
# 3  Through a series of unfortunate events, three ...
# 4  Good-hearted teenager William always lived in ...
#
#                                                 crew  \
# 0  Michael B. Jordan, Adonis Creed, Tessa Thompso...
# 1  Sam Worthington, Jake Sully, Zoe Saldaña, Neyt...
# 2  Chris Pratt, Mario (voice), Anya Taylor-Joy, P...
# 3  Óscar Barberán, Thut (voice), Ana Esther Albor...
# 4  Skeet Ulrich, Roy Cameron, Anne Heche, Dr Quin...
#
#                     orig_title     status            orig_lang     budget_x  \
# 0                    Creed III   Released              English   75000000.0
# 1     Avatar: The Way of Water   Released              English  460000000.0
# 2  The Super Mario Bros. Movie   Released              English  100000000.0
# 3                       Momias   Released   Spanish, Castilian   12300000.0
# 4                    Supercell   Released              English   77000000.0
#
#         revenue country
# 0  2.716167e+08      AU
# 1  2.316795e+09      AU
# 2  7.244590e+08      AU
# 3  3.420000e+07      AU
# 4  3.409420e+08      US

# %% [markdown]
# Kita lakukan hal yang sama untuk judul film pada dataset IMDb seperti pada netflix

# %%
data_imdb['orig_title'] = data_imdb['orig_title'].str.lower()
data_imdb['orig_title'] = data_imdb['orig_title'].str.strip()
data_imdb['orig_title']
# Out:
# 0                                      creed iii
# 1                       avatar: the way of water
# 2                    the super mario bros. movie
# 3                                         momias
# 4                                      supercell
#                           ...
# 10173                         20th century women
# 10174    delta force 2: the colombian connection
# 10175                           the russia house
# 10176           darkman ii: the return of durant
# 10177         the swan princess: a royal wedding
# Name: orig_title, Length: 10178, dtype: object

# %% [markdown]
# # Data Preparation

# %% [markdown]
# ### Join netflix & IMDb dataframe

# %% [markdown]
# Kita gabungkan dataframe netflix & IMDb untuk mendapatkan kolom "revenue", "budget", dan "score" dari IMDb untuk netflix

# %%
df = data_netflix.merge(data_imdb[['date_x', 'orig_title', 'crew', 'orig_lang', 'budget_x', 'revenue', 'score', 'genre']],left_on='title',right_on='orig_title',how='inner')
df = df.drop(['orig_title'], axis=1)

# %% [markdown]
# Kita lakukan backup dengan cara assign dataframe hasil join "df" ke variabel baru "data"

# %%
data = df
data
# Out:
#      show_id   type                                         title  \
# 0         s7  Movie              my little pony: a new generation
# 1        s10  Movie                                  the starling
# 2        s19  Movie                                     intrusion
# 3        s24  Movie  go! go! cory carson: chrissy takes the wheel
# 4        s28  Movie                                     grown ups
# ...      ...    ...                                           ...
# 1334   s8791  Movie                 you don't mess with the zohan
# 1335   s8792  Movie                                   young adult
# 1336   s8803  Movie                                        zodiac
# 1337   s8805  Movie                                    zombieland
# 1338   s8806  Movie                                          zoom
#
#                            director  \
# 0     Robert Cullen, José Luis Ucha
# 1                    Theodore Melfi
# 2                        Adam Salky
# 3           Alex Woo, Stanley Moore
# 4                      Dennis Dugan
# ...                             ...
# 1334                   Dennis Dugan
# 1335                  Jason Reitman
# 1336                  David Fincher
# 1337                Ruben Fleischer
# 1338                   Peter Hewitt
#
#                                                    cast        country  \
# 0     Vanessa Hudgens, Kimiko Glenn, James Marsden, ...            NaN
# 1     Melissa McCarthy, Chris O'Dowd, Kevin Kline, T...  United States
# 2     Freida Pinto, Logan Marshall-Green, Robert Joh...            NaN
# 3     Maisie Benson, Paul Killam, Kerry Gudjohnsen, ...            NaN
# 4     Adam Sandler, Kevin James, Chris Rock, David S...  United States
# ...                                                 ...            ...
# 1334  Adam Sandler, John Turturro, Emmanuelle Chriqu...  United States
# 1335  Charlize Theron, Patton Oswalt, Patrick Wilson...  United States
# 1336  Mark Ruffalo, Jake Gyllenhaal, Robert Downey J...  United States
# 1337  Jesse Eisenberg, Woody Harrelson, Emma Stone, ...  United States
# 1338  Tim Allen, Courteney Cox, Chevy Chase, Kate Ma...  United States
#
#               date_added  release_year rating duration  \
# 0     September 24, 2021          2021     PG   91 min
# 1     September 24, 2021          2021  PG-13  104 min
# 2     September 22, 2021          2021  TV-14   94 min
# 3     September 21, 2021          2021   TV-Y   61 min
# 4     September 20, 2021          2010  PG-13  103 min
# ...                  ...           ...    ...      ...
# 1334   September 1, 2019          2008     UR  113 min
# 1335   November 20, 2019          2011      R   94 min
# 1336   November 20, 2019          2007      R  158 min
# 1337    November 1, 2019          2009      R   88 min
# 1338    January 11, 2020          2006     PG   88 min
#
#                                  listed_in  \
# 0                 Children & Family Movies
# 1                         Comedies, Dramas
# 2                                Thrillers
# 3                 Children & Family Movies
# 4                                 Comedies
# ...                                    ...
# 1334          Action & Adventure, Comedies
# 1335  Comedies, Dramas, Independent Movies
# 1336        Cult Movies, Dramas, Thrillers
# 1337               Comedies, Horror Movies
# 1338    Children & Family Movies, Comedies
#
#                                             description       date_x  \
# 0     Equestria's divided. But a bright-eyed hero be...  04/16/2022
# 1     A woman adjusting to life after a loss contend...  09/17/2021
# 2     After a deadly home invasion at a couple’s new...  09/22/2021
# 3     From arcade games to sled days and hiccup cure...  09/21/2021
# 4     Mourning the loss of their beloved junior high...  06/24/2010
# ...                                                 ...          ...
# 1334  An Israeli counterterrorism soldier with a sec...  08/15/2008
# 1335  When a divorced writer gets a letter from an o...  01/19/2012
# 1336  A political cartoonist, a crime reporter and a...  05/17/2007
# 1337  Looking to survive in a world taken over by zo...  12/03/2009
# 1338  Dragged from civilian life, a former superhero...  08/11/2006
#
#                                                    crew orig_lang  \
# 0     Vanessa Hudgens, Sunny Starscout (voice), Kimi...   English
# 1     Melissa McCarthy, Lilly Maynard, Chris O'Dowd,...   English
# 2     Freida Pinto, Meera Parsons, Logan Marshall-Gr...   English
# 3     Maisie Benson, , Paul Killam, , Kerry Gudjohns...   English
# 4     Adam Sandler, Lenny Feder, Kevin James, Eric L...   English
# ...                                                 ...       ...
# 1334  Adam Sandler, Zohan Dvir, Emmanuelle Chriqui, ...   English
# 1335  Charlize Theron, Mavis Gary, Patton Oswalt, Ma...   English
# 1336  Jake Gyllenhaal, Robert Graysmith, Mark Ruffal...   English
# 1337  Woody Harrelson, Tallahassee, Jesse Eisenberg,...   English
# 1338  Tim Allen, Jack Sheppard, Courteney Cox, Marsh...   English
#
#          budget_x      revenue  score  \
# 0      38211149.2    4100000.0   78.0
# 1     100000000.0  369861963.8   71.0
# 2      82000000.0  618157116.2   60.0
# 3      93000000.0  477850338.2   58.0
# 4      75000000.0  272222420.0   64.0
# ...           ...          ...    ...
# 1334   90000000.0  204313400.0   57.0
# 1335   12000000.0   22750356.0   58.0
# 1336   85000000.0   83080084.0   75.0
# 1337   23600000.0  102236596.0   73.0
# 1338   35000000.0   12506188.0   54.0
#
#                                                   genre
# 0         Animation, Family, Fantasy, Comedy, Adventure
# 1                                                 Drama
# 2                                              Thriller
# 3                                     Animation, Family
# 4                                                Comedy
# ...                                                 ...
# 1334                                     Comedy, Action
# 1335                                      Comedy, Drama
# 1336                    Crime, Drama, Mystery, Thriller
# 1337                                     Comedy, Horror
# 1338  Family, Comedy, Adventure, Action, Science Fic...
#
# [1339 rows x 19 columns]

# %% [markdown]
# ## Data Cleansing & Formating
#
# Kita lakukan pengecekan jenis data, jumlah unik, jumlah missing value, dan persentase missing value dari dataframe hasil join.
#
# Untuk itu kita buat suatu fungsi pengecekan yang dapat digunakan untuk aktivitas serupa di masa depan

# %%
def df_diagnostics(data_frame):
    types = data_frame.dtypes
    distinct = data_frame.nunique()
    count_na = data_frame.isna().sum()
    percent_na = round((data_frame.isna().sum()/len(data))*100, 3)

    df_check = pd.concat([types, distinct, count_na, percent_na], axis=1)
    df_check.reset_index(level=0, inplace=True)
    df_check.rename(columns = {'index':'column', 0:'types', 1:'distinct', 2:'count_na', 3: 'percent_na'}, inplace = True)

    print('dimensi data: ', data.shape)

    return df_check

# %%
df_diagnostics(data)
# Out:
# dimensi data:  (1339, 19)
#           column    types  distinct  count_na  percent_na
# 0        show_id   object      1233         0       0.000
# 1           type   object         1         0       0.000
# 2          title   object      1233         0       0.000
# 3       director   object       930         8       0.597
# 4           cast   object      1213        21       1.568
# 5        country   object       250        32       2.390
# 6     date_added   object       572         0       0.000
# 7   release_year    int64        62         0       0.000
# 8         rating   object        12         0       0.000
# 9       duration   object       119         0       0.000
# 10     listed_in   object       177         0       0.000
# 11   description   object      1233         0       0.000
# 12        date_x   object      1129         0       0.000
# 13          crew   object      1297         2       0.149
# 14     orig_lang   object        17         0       0.000
# 15      budget_x  float64       456         0       0.000
# 16       revenue  float64      1235         0       0.000
# 17         score  float64        48         0       0.000
# 18         genre   object       547         2       0.149

# %% [markdown]
# Terdapat 2 kolom yang memiliki missing value yaitu cast & country, kita simpan dahulu untuk analisis lanjutan.

# %% [markdown]
# ### Formatting Date
#
# Untuk kolom date_added dan date_x kita ubah dari object menjadi datetime untuk pengolahan data tanggal lebih lanjut.
#
# Kita tambahkan kolom tahun dan bulan penambahan konten film ke netflix

# %%
data['date_added'] = pd.to_datetime(data['date_added'])
data['date_x'] = pd.to_datetime(data['date_x'])
data['year_added'] = data['date_added'].dt.year.astype(int)
data['month_added'] = data['date_added'].dt.month.astype(int)
data
# Out:
#      show_id   type                                         title  \
# 0         s7  Movie              my little pony: a new generation
# 1        s10  Movie                                  the starling
# 2        s19  Movie                                     intrusion
# 3        s24  Movie  go! go! cory carson: chrissy takes the wheel
# 4        s28  Movie                                     grown ups
# ...      ...    ...                                           ...
# 1334   s8791  Movie                 you don't mess with the zohan
# 1335   s8792  Movie                                   young adult
# 1336   s8803  Movie                                        zodiac
# 1337   s8805  Movie                                    zombieland
# 1338   s8806  Movie                                          zoom
#
#                            director  \
# 0     Robert Cullen, José Luis Ucha
# 1                    Theodore Melfi
# 2                        Adam Salky
# 3           Alex Woo, Stanley Moore
# 4                      Dennis Dugan
# ...                             ...
# 1334                   Dennis Dugan
# 1335                  Jason Reitman
# 1336                  David Fincher
# 1337                Ruben Fleischer
# 1338                   Peter Hewitt
#
#                                                    cast        country  \
# 0     Vanessa Hudgens, Kimiko Glenn, James Marsden, ...            NaN
# 1     Melissa McCarthy, Chris O'Dowd, Kevin Kline, T...  United States
# 2     Freida Pinto, Logan Marshall-Green, Robert Joh...            NaN
# 3     Maisie Benson, Paul Killam, Kerry Gudjohnsen, ...            NaN
# 4     Adam Sandler, Kevin James, Chris Rock, David S...  United States
# ...                                                 ...            ...
# 1334  Adam Sandler, John Turturro, Emmanuelle Chriqu...  United States
# 1335  Charlize Theron, Patton Oswalt, Patrick Wilson...  United States
# 1336  Mark Ruffalo, Jake Gyllenhaal, Robert Downey J...  United States
# 1337  Jesse Eisenberg, Woody Harrelson, Emma Stone, ...  United States
# 1338  Tim Allen, Courteney Cox, Chevy Chase, Kate Ma...  United States
#
#      date_added  release_year rating duration  ...  \
# 0    2021-09-24          2021     PG   91 min  ...
# 1    2021-09-24          2021  PG-13  104 min  ...
# 2    2021-09-22          2021  TV-14   94 min  ...
# 3    2021-09-21          2021   TV-Y   61 min  ...
# 4    2021-09-20          2010  PG-13  103 min  ...
# ...         ...           ...    ...      ...  ...
# 1334 2019-09-01          2008     UR  113 min  ...
# 1335 2019-11-20          2011      R   94 min  ...
# 1336 2019-11-20          2007      R  158 min  ...
# 1337 2019-11-01          2009      R   88 min  ...
# 1338 2020-01-11          2006     PG   88 min  ...
#
#                                             description     date_x  \
# 0     Equestria's divided. But a bright-eyed hero be... 2022-04-16
# 1     A woman adjusting to life after a loss contend... 2021-09-17
# 2     After a deadly home invasion at a couple’s new... 2021-09-22
# 3     From arcade games to sled days and hiccup cure... 2021-09-21
# 4     Mourning the loss of their beloved junior high... 2010-06-24
# ...                                                 ...        ...
# 1334  An Israeli counterterrorism soldier with a sec... 2008-08-15
# 1335  When a divorced writer gets a letter from an o... 2012-01-19
# 1336  A political cartoonist, a crime reporter and a... 2007-05-17
# 1337  Looking to survive in a world taken over by zo... 2009-12-03
# 1338  Dragged from civilian life, a former superhero... 2006-08-11
#
#                                                    crew orig_lang  \
# 0     Vanessa Hudgens, Sunny Starscout (voice), Kimi...   English
# 1     Melissa McCarthy, Lilly Maynard, Chris O'Dowd,...   English
# 2     Freida Pinto, Meera Parsons, Logan Marshall-Gr...   English
# 3     Maisie Benson, , Paul Killam, , Kerry Gudjohns...   English
# 4     Adam Sandler, Lenny Feder, Kevin James, Eric L...   English
# ...                                                 ...       ...
# 1334  Adam Sandler, Zohan Dvir, Emmanuelle Chriqui, ...   English
# 1335  Charlize Theron, Mavis Gary, Patton Oswalt, Ma...   English
# 1336  Jake Gyllenhaal, Robert Graysmith, Mark Ruffal...   English
# 1337  Woody Harrelson, Tallahassee, Jesse Eisenberg,...   English
# 1338  Tim Allen, Jack Sheppard, Courteney Cox, Marsh...   English
#
#          budget_x      revenue  score  \
# 0      38211149.2    4100000.0   78.0
# 1     100000000.0  369861963.8   71.0
# 2      82000000.0  618157116.2   60.0
# 3      93000000.0  477850338.2   58.0
# 4      75000000.0  272222420.0   64.0
# ...           ...          ...    ...
# 1334   90000000.0  204313400.0   57.0
# 1335   12000000.0   22750356.0   58.0
# 1336   85000000.0   83080084.0   75.0
# 1337   23600000.0  102236596.0   73.0
# 1338   35000000.0   12506188.0   54.0
#
#                                                   genre year_added  \
# 0         Animation, Family, Fantasy, Comedy, Adventure       2021
# 1                                                 Drama       2021
# 2                                              Thriller       2021
# 3                                     Animation, Family       2021
# 4                                                Comedy       2021
# ...                                                 ...        ...
# 1334                                     Comedy, Action       2019
# 1335                                      Comedy, Drama       2019
# 1336                    Crime, Drama, Mystery, Thriller       2019
# 1337                                     Comedy, Horror       2019
# 1338  Family, Comedy, Adventure, Action, Science Fic...       2020
#
#       month_added
# 0               9
# 1               9
# 2               9
# 3               9
# 4               9
# ...           ...
# 1334            9
# 1335           11
# 1336           11
# 1337           11
# 1338            1
#
# [1339 rows x 21 columns]

# %% [markdown]
# Kita cek apakah join kita ini sudah benar antara netflix dengan IMDb, karena kita tahu bahwa banyak film dengan nama yang sama tetapi ternyata itu adalah dua film berbeda. Sehingga perlu kita cek seharusnya tanggal rilis film tidak mungkin lebih baru daripada tanggal ditambahkannya konten ke netflix.
#
# Kita buat dahulu kolom baru untuk menghitung selisih date_added dengan date_x

# %%
data['release_day_gap'] = (data['date_added'] - data['date_x']).dt.days.astype(int)
data['release_day_gap']
# Out:
# 0       -204
# 1          7
# 2          0
# 3          0
# 4       4106
#         ...
# 1334    4034
# 1335    2862
# 1336    4570
# 1337    3620
# 1338    4901
# Name: release_day_gap, Length: 1339, dtype: int64

# %% [markdown]
# Kita cek apakah ada release_day_gap yang minus

# %%
print((len(data[data['release_day_gap'] < 0])/len(data))*100, len(data[data['release_day_gap'] < 0]))
data[data['release_day_gap'] < 0].head()
# Out:
# 3.7341299477221805 50
#     show_id   type                             title  \
# 0        s7  Movie  my little pony: a new generation
# 16      s87  Movie                              prey
# 34     s145  Movie                       house party
# 108    s403  Movie   the last letter from your lover
# 122    s465  Movie               gunpowder milkshake
#
#                           director  \
# 0    Robert Cullen, José Luis Ucha
# 16                   Thomas Sieben
# 34                 Reginald Hudlin
# 108             Augustine Frizzell
# 122                Navot Papushado
#
#                                                   cast         country  \
# 0    Vanessa Hudgens, Kimiko Glenn, James Marsden, ...             NaN
# 16   David Kross, Hanno Koffler, Maria Ehrich, Robe...             NaN
# 34   Christopher Reid, Christopher Martin, Robin Ha...   United States
# 108  Shailene Woodley, Felicity Jones, Callum Turne...  United Kingdom
# 122  Karen Gillan, Lena Headey, Carla Gugino, Chloe...             NaN
#
#     date_added  release_year rating duration  ...     date_x  \
# 0   2021-09-24          2021     PG   91 min  ... 2022-04-16
# 16  2021-09-10          2021  TV-MA   87 min  ... 2022-08-05
# 34  2021-09-01          1990      R  104 min  ... 2023-02-01
# 108 2021-07-23          2021  TV-MA  111 min  ... 2021-08-06
# 122 2021-07-14          2021      R  115 min  ... 2021-07-15
#
#                                                   crew orig_lang    budget_x  \
# 0    Vanessa Hudgens, Sunny Starscout (voice), Kimi...   English  38211149.2
# 16   Amber Midthunder, Naru, Dakota Beavers, Taabe,...   English  65000000.0
# 34   Jacob Latimore, Kevin, Tosin Cole, Damon, Kare...   English  90544000.0
# 108  Shailene Woodley, Jennifer Stirling, Felicity ...   English    515001.4
# 122  Karen Gillan, Sam, Lena Headey, Scarlet, Chloe...   English  30000000.0
#
#          revenue  score                                          genre  \
# 0      4100000.0   78.0  Animation, Family, Fantasy, Comedy, Adventure
# 16           0.0   78.0              Thriller, Action, Science Fiction
# 34   519948264.6   64.0                                         Comedy
# 108    1451974.0   75.0                                 Drama, Romance
# 122    1015760.0   64.0                        Action, Crime, Thriller
#
#      year_added month_added  release_day_gap
# 0          2021           9             -204
# 16         2021           9             -329
# 34         2021           9             -518
# 108        2021           7              -14
# 122        2021           7               -1
#
# [5 rows x 22 columns]

# %% [markdown]
# Cek bentuk data release_day_gap lebih dari 0

# %%
data[data['release_day_gap'] >= 0].head(20)
# Out:
#    show_id   type                                         title  \
# 1      s10  Movie                                  the starling
# 2      s19  Movie                                     intrusion
# 3      s24  Movie  go! go! cory carson: chrissy takes the wheel
# 4      s28  Movie                                     grown ups
# 5      s29  Movie                                    dark skies
# 6      s30  Movie                                      paranoia
# 7      s39  Movie                           birth of the dragon
# 8      s42  Movie                                          jaws
# 9      s43  Movie                                        jaws 2
# 10     s45  Movie                             jaws: the revenge
# 11     s47  Movie                                    safe house
# 12     s49  Movie                                  training day
# 13     s65  Movie                                    nightbooks
# 14     s69  Movie                                    schumacher
# 15     s82  Movie                                          kate
# 17     s87  Movie                                          prey
# 18     s87  Movie                                          prey
# 19     s91  Movie                                paradise hills
# 20    s114  Movie                        afterlife of the party
# 21    s128  Movie                            a cinderella story
#
#                                              director  \
# 1                                      Theodore Melfi
# 2                                          Adam Salky
# 3                             Alex Woo, Stanley Moore
# 4                                        Dennis Dugan
# 5                                       Scott Stewart
# 6                                      Robert Luketic
# 7                                        George Nolfi
# 8                                    Steven Spielberg
# 9                                      Jeannot Szwarc
# 10                                     Joseph Sargent
# 11                                    Daniel Espinosa
# 12                                      Antoine Fuqua
# 13                                    David Yarovesky
# 14  Hanns-Bruno Kammertöns, Vanessa Nöcker, Michae...
# 15                              Cedric Nicolas-Troyan
# 17                                      Thomas Sieben
# 18                                      Thomas Sieben
# 19                                   Alice Waddington
# 20                                      Stephen Herek
# 21                                        Mark Rosman
#
#                                                  cast  \
# 1   Melissa McCarthy, Chris O'Dowd, Kevin Kline, T...
# 2   Freida Pinto, Logan Marshall-Green, Robert Joh...
# 3   Maisie Benson, Paul Killam, Kerry Gudjohnsen, ...
# 4   Adam Sandler, Kevin James, Chris Rock, David S...
# 5   Keri Russell, Josh Hamilton, J.K. Simmons, Dak...
# 6   Liam Hemsworth, Gary Oldman, Amber Heard, Harr...
# 7   Billy Magnussen, Ron Yuan, Qu Jingjing, Terry ...
# 8   Roy Scheider, Robert Shaw, Richard Dreyfuss, L...
# 9   Roy Scheider, Lorraine Gary, Murray Hamilton, ...
# 10  Lorraine Gary, Lance Guest, Mario Van Peebles,...
# 11  Denzel Washington, Ryan Reynolds, Vera Farmiga...
# 12  Denzel Washington, Ethan Hawke, Scott Glenn, T...
# 13       Winslow Fegley, Lidya Jewett, Krysten Ritter
# 14                                 Michael Schumacher
# 15  Mary Elizabeth Winstead, Jun Kunimura, Woody H...
# 17  David Kross, Hanno Koffler, Maria Ehrich, Robe...
# 18  David Kross, Hanno Koffler, Maria Ehrich, Robe...
# 19  Emma Roberts, Danielle Macdonald, Awkwafina, E...
# 20  Victoria Justice, Midori Francis, Robyn Scott,...
# 21  Hilary Duff, Chad Michael Murray, Jennifer Coo...
#
#                                country date_added  release_year rating  \
# 1                        United States 2021-09-24          2021  PG-13
# 2                                  NaN 2021-09-22          2021  TV-14
# 3                                  NaN 2021-09-21          2021   TV-Y
# 4                        United States 2021-09-20          2010  PG-13
# 5                        United States 2021-09-19          2013  PG-13
# 6         United States, India, France 2021-09-19          2013  PG-13
# 7         China, Canada, United States 2021-09-16          2017  PG-13
# 8                        United States 2021-09-16          1975     PG
# 9                        United States 2021-09-16          1978     PG
# 10                       United States 2021-09-16          1987  PG-13
# 11  South Africa, United States, Japan 2021-09-16          2012      R
# 12                       United States 2021-09-16          2001      R
# 13                                 NaN 2021-09-15          2021  TV-PG
# 14                                 NaN 2021-09-15          2021  TV-14
# 15                       United States 2021-09-10          2021      R
# 17                                 NaN 2021-09-10          2021  TV-MA
# 18                                 NaN 2021-09-10          2021  TV-MA
# 19                Spain, United States 2021-09-09          2019  TV-MA
# 20                                 NaN 2021-09-02          2021  TV-PG
# 21               United States, Canada 2021-09-01          2004     PG
#
#    duration  ...     date_x  \
# 1   104 min  ... 2021-09-17
# 2    94 min  ... 2021-09-22
# 3    61 min  ... 2021-09-21
# 4   103 min  ... 2010-06-24
# 5    97 min  ... 2013-03-13
# 6   106 min  ... 2013-10-03
# 7    96 min  ... 2016-09-13
# 8   124 min  ... 1975-11-26
# 9   116 min  ... 1978-06-16
# 10   91 min  ... 1987-07-17
# 11  115 min  ... 2012-02-09
# 12  122 min  ... 2001-11-15
# 13  103 min  ... 2021-09-15
# 14  113 min  ... 2021-09-15
# 15  106 min  ... 2021-09-10
# 17   87 min  ... 2021-09-10
# 18   87 min  ... 2009-09-09
# 19   95 min  ... 2020-02-05
# 20  110 min  ... 2021-09-02
# 21   95 min  ... 2010-03-31
#
#                                                  crew orig_lang     budget_x  \
# 1   Melissa McCarthy, Lilly Maynard, Chris O'Dowd,...   English  100000000.0
# 2   Freida Pinto, Meera Parsons, Logan Marshall-Gr...   English   82000000.0
# 3   Maisie Benson, , Paul Killam, , Kerry Gudjohns...   English   93000000.0
# 4   Adam Sandler, Lenny Feder, Kevin James, Eric L...   English   75000000.0
# 5   Keri Russell, Lacy Barrett, Josh Hamilton, Dan...   English    3500000.0
# 6   Liam Hemsworth, Adam Cassidy, Harrison Ford, J...   English   40000000.0
# 7   Philip Ng Wan-Lung, Bruce Lee, Billy Magnussen...   English   31000000.0
# 8   Roy Scheider, Police Chief Martin Brody, Rober...   English   12000000.0
# 9   Roy Scheider, Police Chief Martin Brody, Lorra...   English   20000000.0
# 10  Lorraine Gary, Ellen Brody, Lance Guest, Micha...   English   23000000.0
# 11  Denzel Washington, Tobin Frost, Ryan Reynolds,...   English   85000000.0
# 12  Denzel Washington, Alonzo Harris, Ethan Hawke,...   English   45000000.0
# 13  Winslow Fegley, Alex, Lidya Jewett, Yasmin, Kr...   English  119600000.0
# 14  Michael Schumacher, Self (archive footage), Mi...   English   79500000.0
# 15  Mary Elizabeth Winstead, Kate, Miku Martineau,...   English   37800000.0
# 17  David Kross, Roman, Hanno Koffler, Albert, Mar...    German   65000000.0
# 18  Bridget Moynahan, Amy Newman, Peter Weller, To...   English   65000000.0
# 19  Emma Roberts, Uma, Eiza González, Amarna, Mill...   English    6000000.0
# 20  Victoria Justice, Cassie, Midori Francis, Lisa...   English   53400000.0
# 21  Hilary Duff, Sam Montgomery, Chad Michael Murr...   English   19000000.0
#
#         revenue  score                               genre  year_added  \
# 1   369861963.8   71.0                               Drama        2021
# 2   618157116.2   60.0                            Thriller        2021
# 3   477850338.2   58.0                   Animation, Family        2021
# 4   272222420.0   64.0                              Comedy        2021
# 5    27704111.0   63.0   Science Fiction, Thriller, Horror        2021
# 6    16340767.0   57.0                     Drama, Thriller        2021
# 7     7220490.0   58.0                       Action, Drama        2021
# 8   482947378.0   77.0         Horror, Thriller, Adventure        2021
# 9   208900376.0   60.0                    Horror, Thriller        2021
# 10   51881013.0   41.0         Adventure, Thriller, Horror        2021
# 11  207884401.0   64.0                    Action, Thriller        2021
# 12  104505352.0   75.0                Action, Crime, Drama        2021
# 13  400881081.0   63.0             Fantasy, Family, Horror        2021
# 14  708023892.4   74.0                         Documentary        2021
# 15  638719244.4   67.0                              Action        2021
# 17          0.0   47.0                            Thriller        2021
# 18          0.0   57.0         Adventure, Horror, Thriller        2021
# 19   33100520.4   60.0  Fantasy, Science Fiction, Thriller        2021
# 20  315069539.8   68.0              Fantasy, Comedy, Drama        2021
# 21   70112484.0   65.0             Comedy, Family, Romance        2021
#
#    month_added  release_day_gap
# 1            9                7
# 2            9                0
# 3            9                0
# 4            9             4106
# 5            9             3112
# 6            9             2908
# 7            9             1829
# 8            9            16731
# 9            9            15798
# 10           9            12480
# 11           9             3507
# 12           9             7245
# 13           9                0
# 14           9                0
# 15           9                0
# 17           9                0
# 18           9             4384
# 19           9              582
# 20           9                0
# 21           9             4172
#
# [20 rows x 22 columns]

# %% [markdown]
# ### Cast & Crew
#
# Ternyata selain release_day_gap, ada keanehan pada cast (pemeran film pada data netflix) yang berbeda dengan crew (pemeran film pada data IMDb) meskipun nama film sama dan release_day_gap >= 0, sehingga perlu kita cek juga kesamaan cast & crew

# %% [markdown]
# Kolom cast & crew ini berbentuk string tetapi di dalamnya berisi kumpulan nama/string, disamping itu biasanya pemeran utama dimunculkan pada paling awal di kolom cast & crew. Menggunakan logika itu kita dapat memfilter pemeran utama pada cast & crew itu sama

# %%
data = data[data['release_day_gap'] >= 0]
data = data[data['cast'].str.split(',').str[0].str.lower().str.strip() == data['crew'].str.split(',').str[0].str.lower().str.strip()]
data
# Out:
#      show_id   type                                         title  \
# 1        s10  Movie                                  the starling
# 2        s19  Movie                                     intrusion
# 3        s24  Movie  go! go! cory carson: chrissy takes the wheel
# 4        s28  Movie                                     grown ups
# 5        s29  Movie                                    dark skies
# ...      ...    ...                                           ...
# 1330   s8767  Movie                                           xxx
# 1332   s8768  Movie                       xxx: state of the union
# 1334   s8791  Movie                 you don't mess with the zohan
# 1335   s8792  Movie                                   young adult
# 1338   s8806  Movie                                          zoom
#
#                      director  \
# 1              Theodore Melfi
# 2                  Adam Salky
# 3     Alex Woo, Stanley Moore
# 4                Dennis Dugan
# 5               Scott Stewart
# ...                       ...
# 1330                Rob Cohen
# 1332             Lee Tamahori
# 1334             Dennis Dugan
# 1335            Jason Reitman
# 1338             Peter Hewitt
#
#                                                    cast        country  \
# 1     Melissa McCarthy, Chris O'Dowd, Kevin Kline, T...  United States
# 2     Freida Pinto, Logan Marshall-Green, Robert Joh...            NaN
# 3     Maisie Benson, Paul Killam, Kerry Gudjohnsen, ...            NaN
# 4     Adam Sandler, Kevin James, Chris Rock, David S...  United States
# 5     Keri Russell, Josh Hamilton, J.K. Simmons, Dak...  United States
# ...                                                 ...            ...
# 1330  Vin Diesel, Asia Argento, Marton Csokas, Samue...  United States
# 1332  Ice Cube, Samuel L. Jackson, Willem Dafoe, Sco...  United States
# 1334  Adam Sandler, John Turturro, Emmanuelle Chriqu...  United States
# 1335  Charlize Theron, Patton Oswalt, Patrick Wilson...  United States
# 1338  Tim Allen, Courteney Cox, Chevy Chase, Kate Ma...  United States
#
#      date_added  release_year rating duration  ...     date_x  \
# 1    2021-09-24          2021  PG-13  104 min  ... 2021-09-17
# 2    2021-09-22          2021  TV-14   94 min  ... 2021-09-22
# 3    2021-09-21          2021   TV-Y   61 min  ... 2021-09-21
# 4    2021-09-20          2010  PG-13  103 min  ... 2010-06-24
# 5    2021-09-19          2013  PG-13   97 min  ... 2013-03-13
# ...         ...           ...    ...      ...  ...        ...
# 1330 2019-01-01          2002  PG-13  124 min  ... 2002-10-03
# 1332 2019-01-01          2005  PG-13  101 min  ... 2005-04-28
# 1334 2019-09-01          2008     UR  113 min  ... 2008-08-15
# 1335 2019-11-20          2011      R   94 min  ... 2012-01-19
# 1338 2020-01-11          2006     PG   88 min  ... 2006-08-11
#
#                                                    crew orig_lang  \
# 1     Melissa McCarthy, Lilly Maynard, Chris O'Dowd,...   English
# 2     Freida Pinto, Meera Parsons, Logan Marshall-Gr...   English
# 3     Maisie Benson, , Paul Killam, , Kerry Gudjohns...   English
# 4     Adam Sandler, Lenny Feder, Kevin James, Eric L...   English
# 5     Keri Russell, Lacy Barrett, Josh Hamilton, Dan...   English
# ...                                                 ...       ...
# 1330  Vin Diesel, Xander Cage, Asia Argento, Yelena,...   English
# 1332  Ice Cube, Darius Stone / xXx, Samuel L. Jackso...   English
# 1334  Adam Sandler, Zohan Dvir, Emmanuelle Chriqui, ...   English
# 1335  Charlize Theron, Mavis Gary, Patton Oswalt, Ma...   English
# 1338  Tim Allen, Jack Sheppard, Courteney Cox, Marsh...   English
#
#          budget_x      revenue  score  \
# 1     100000000.0  369861963.8   71.0
# 2      82000000.0  618157116.2   60.0
# 3      93000000.0  477850338.2   58.0
# 4      75000000.0  272222420.0   64.0
# 5       3500000.0   27704111.0   63.0
# ...           ...          ...    ...
# 1330   70000000.0  267200000.0   59.0
# 1332   60000000.0   71073932.0   50.0
# 1334   90000000.0  204313400.0   57.0
# 1335   12000000.0   22750356.0   58.0
# 1338   35000000.0   12506188.0   54.0
#
#                                                   genre  year_added  \
# 1                                                 Drama        2021
# 2                                              Thriller        2021
# 3                                     Animation, Family        2021
# 4                                                Comedy        2021
# 5                     Science Fiction, Thriller, Horror        2021
# ...                                                 ...         ...
# 1330                        Action, Adventure, Thriller        2019
# 1332        Action, Adventure, Crime, Mystery, Thriller        2019
# 1334                                     Comedy, Action        2019
# 1335                                      Comedy, Drama        2019
# 1338  Family, Comedy, Adventure, Action, Science Fic...        2020
#
#      month_added  release_day_gap
# 1              9                7
# 2              9                0
# 3              9                0
# 4              9             4106
# 5              9             3112
# ...          ...              ...
# 1330           1             5934
# 1332           1             4996
# 1334           9             4034
# 1335          11             2862
# 1338           1             4901
#
# [968 rows x 22 columns]

# %% [markdown]
# Dari hasil pengecekan terdapat 980 rows tersisa dari kedua dataframe yang di-join, kemudia kita lakukan pengecekkan diagnostik kembali

# %%
df_diagnostics(data)
# Out:
# dimensi data:  (968, 22)
#              column           types  distinct  count_na  percent_na
# 0           show_id          object       949         0       0.000
# 1              type          object         1         0       0.000
# 2             title          object       949         0       0.000
# 3          director          object       727         5       0.517
# 4              cast          object       949         0       0.000
# 5           country          object       196        19       1.963
# 6        date_added  datetime64[ns]       459         0       0.000
# 7      release_year           int64        59         0       0.000
# 8            rating          object        12         0       0.000
# 9          duration          object       109         0       0.000
# 10        listed_in          object       155         0       0.000
# 11      description          object       949         0       0.000
# 12           date_x  datetime64[ns]       856         0       0.000
# 13             crew          object       949         0       0.000
# 14        orig_lang          object        13         0       0.000
# 15         budget_x         float64       358         0       0.000
# 16          revenue         float64       941         0       0.000
# 17            score         float64        46         0       0.000
# 18            genre          object       436         0       0.000
# 19       year_added           int64        10         0       0.000
# 20      month_added           int64        12         0       0.000
# 21  release_day_gap           int64       751         0       0.000

# %% [markdown]
# Karena hanya 18 row yang memiliki missing value, alangkah baiknya kita dari dataframe

# %%
data = data.dropna(axis = 0)

df_diagnostics(data)
# Out:
# dimensi data:  (944, 22)
#              column           types  distinct  count_na  percent_na
# 0           show_id          object       925         0         0.0
# 1              type          object         1         0         0.0
# 2             title          object       925         0         0.0
# 3          director          object       710         0         0.0
# 4              cast          object       925         0         0.0
# 5           country          object       196         0         0.0
# 6        date_added  datetime64[ns]       444         0         0.0
# 7      release_year           int64        59         0         0.0
# 8            rating          object        12         0         0.0
# 9          duration          object       106         0         0.0
# 10        listed_in          object       152         0         0.0
# 11      description          object       925         0         0.0
# 12           date_x  datetime64[ns]       838         0         0.0
# 13             crew          object       925         0         0.0
# 14        orig_lang          object        13         0         0.0
# 15         budget_x         float64       343         0         0.0
# 16          revenue         float64       919         0         0.0
# 17            score         float64        46         0         0.0
# 18            genre          object       426         0         0.0
# 19       year_added           int64        10         0         0.0
# 20      month_added           int64        12         0         0.0
# 21  release_day_gap           int64       746         0         0.0

# %% [markdown]
# ### Firat Country
#
# Dari dataframe yang kita miliki ternyata kolom country ini tidak hanya memiliki satu nama negara, sehingga kita perlu ambil negara yang muncul paling awal

# %%
data['first_country'] = data['country'].apply(lambda x: x.split(",")[0])
data['first_country'].head()


data
# Out:
#      show_id   type                          title          director  \
# 1        s10  Movie                   the starling    Theodore Melfi
# 4        s28  Movie                      grown ups      Dennis Dugan
# 5        s29  Movie                     dark skies     Scott Stewart
# 6        s30  Movie                       paranoia    Robert Luketic
# 8        s42  Movie                           jaws  Steven Spielberg
# ...      ...    ...                            ...               ...
# 1330   s8767  Movie                            xxx         Rob Cohen
# 1332   s8768  Movie        xxx: state of the union      Lee Tamahori
# 1334   s8791  Movie  you don't mess with the zohan      Dennis Dugan
# 1335   s8792  Movie                    young adult     Jason Reitman
# 1338   s8806  Movie                           zoom      Peter Hewitt
#
#                                                    cast  \
# 1     Melissa McCarthy, Chris O'Dowd, Kevin Kline, T...
# 4     Adam Sandler, Kevin James, Chris Rock, David S...
# 5     Keri Russell, Josh Hamilton, J.K. Simmons, Dak...
# 6     Liam Hemsworth, Gary Oldman, Amber Heard, Harr...
# 8     Roy Scheider, Robert Shaw, Richard Dreyfuss, L...
# ...                                                 ...
# 1330  Vin Diesel, Asia Argento, Marton Csokas, Samue...
# 1332  Ice Cube, Samuel L. Jackson, Willem Dafoe, Sco...
# 1334  Adam Sandler, John Turturro, Emmanuelle Chriqu...
# 1335  Charlize Theron, Patton Oswalt, Patrick Wilson...
# 1338  Tim Allen, Courteney Cox, Chevy Chase, Kate Ma...
#
#                            country date_added  release_year rating duration  \
# 1                    United States 2021-09-24          2021  PG-13  104 min
# 4                    United States 2021-09-20          2010  PG-13  103 min
# 5                    United States 2021-09-19          2013  PG-13   97 min
# 6     United States, India, France 2021-09-19          2013  PG-13  106 min
# 8                    United States 2021-09-16          1975     PG  124 min
# ...                            ...        ...           ...    ...      ...
# 1330                 United States 2019-01-01          2002  PG-13  124 min
# 1332                 United States 2019-01-01          2005  PG-13  101 min
# 1334                 United States 2019-09-01          2008     UR  113 min
# 1335                 United States 2019-11-20          2011      R   94 min
# 1338                 United States 2020-01-11          2006     PG   88 min
#
#       ...                                               crew orig_lang  \
# 1     ...  Melissa McCarthy, Lilly Maynard, Chris O'Dowd,...   English
# 4     ...  Adam Sandler, Lenny Feder, Kevin James, Eric L...   English
# 5     ...  Keri Russell, Lacy Barrett, Josh Hamilton, Dan...   English
# 6     ...  Liam Hemsworth, Adam Cassidy, Harrison Ford, J...   English
# 8     ...  Roy Scheider, Police Chief Martin Brody, Rober...   English
# ...   ...                                                ...       ...
# 1330  ...  Vin Diesel, Xander Cage, Asia Argento, Yelena,...   English
# 1332  ...  Ice Cube, Darius Stone / xXx, Samuel L. Jackso...   English
# 1334  ...  Adam Sandler, Zohan Dvir, Emmanuelle Chriqui, ...   English
# 1335  ...  Charlize Theron, Mavis Gary, Patton Oswalt, Ma...   English
# 1338  ...  Tim Allen, Jack Sheppard, Courteney Cox, Marsh...   English
#
#          budget_x      revenue score  \
# 1     100000000.0  369861963.8  71.0
# 4      75000000.0  272222420.0  64.0
# 5       3500000.0   27704111.0  63.0
# 6      40000000.0   16340767.0  57.0
# 8      12000000.0  482947378.0  77.0
# ...           ...          ...   ...
# 1330   70000000.0  267200000.0  59.0
# 1332   60000000.0   71073932.0  50.0
# 1334   90000000.0  204313400.0  57.0
# 1335   12000000.0   22750356.0  58.0
# 1338   35000000.0   12506188.0  54.0
#
#                                                   genre  year_added  \
# 1                                                 Drama        2021
# 4                                                Comedy        2021
# 5                     Science Fiction, Thriller, Horror        2021
# 6                                       Drama, Thriller        2021
# 8                           Horror, Thriller, Adventure        2021
# ...                                                 ...         ...
# 1330                        Action, Adventure, Thriller        2019
# 1332        Action, Adventure, Crime, Mystery, Thriller        2019
# 1334                                     Comedy, Action        2019
# 1335                                      Comedy, Drama        2019
# 1338  Family, Comedy, Adventure, Action, Science Fic...        2020
#
#       month_added release_day_gap  first_country
# 1               9               7  United States
# 4               9            4106  United States
# 5               9            3112  United States
# 6               9            2908  United States
# 8               9           16731  United States
# ...           ...             ...            ...
# 1330            1            5934  United States
# 1332            1            4996  United States
# 1334            9            4034  United States
# 1335           11            2862  United States
# 1338            1            4901  United States
#
# [944 rows x 23 columns]

# %% [markdown]
# ### Users Demographic
#
# dataframe yang kita miliki memiliki kolom rating yang berisi kode usia user untuk film yang disediakan. Pemetannya menggunakan sistem rating amerika, agar lebih relevan perlu kita ubah ke kelompok usia.

# %%
ratings_ages = {
'TV-PG': 'Older Kids',
'TV-MA': 'Adults',
'TV-Y7-FV': 'Older Kids',
'TV-Y7': 'Older Kids',
'TV-14': 'Teens',
'R': 'Adults',
'TV-Y': 'Kids',
'NR': 'Adults',
'PG-13': 'Teens',
'TV-G': 'Kids',
'PG': 'Older Kids',
'G': 'Kids',
'UR': 'Adults',
'NC-17': 'Adults'
}


data['target_ages'] = data['rating'].replace(ratings_ages)
data['target_ages'].unique()


data
# Out:
#      show_id   type                          title          director  \
# 1        s10  Movie                   the starling    Theodore Melfi
# 4        s28  Movie                      grown ups      Dennis Dugan
# 5        s29  Movie                     dark skies     Scott Stewart
# 6        s30  Movie                       paranoia    Robert Luketic
# 8        s42  Movie                           jaws  Steven Spielberg
# ...      ...    ...                            ...               ...
# 1330   s8767  Movie                            xxx         Rob Cohen
# 1332   s8768  Movie        xxx: state of the union      Lee Tamahori
# 1334   s8791  Movie  you don't mess with the zohan      Dennis Dugan
# 1335   s8792  Movie                    young adult     Jason Reitman
# 1338   s8806  Movie                           zoom      Peter Hewitt
#
#                                                    cast  \
# 1     Melissa McCarthy, Chris O'Dowd, Kevin Kline, T...
# 4     Adam Sandler, Kevin James, Chris Rock, David S...
# 5     Keri Russell, Josh Hamilton, J.K. Simmons, Dak...
# 6     Liam Hemsworth, Gary Oldman, Amber Heard, Harr...
# 8     Roy Scheider, Robert Shaw, Richard Dreyfuss, L...
# ...                                                 ...
# 1330  Vin Diesel, Asia Argento, Marton Csokas, Samue...
# 1332  Ice Cube, Samuel L. Jackson, Willem Dafoe, Sco...
# 1334  Adam Sandler, John Turturro, Emmanuelle Chriqu...
# 1335  Charlize Theron, Patton Oswalt, Patrick Wilson...
# 1338  Tim Allen, Courteney Cox, Chevy Chase, Kate Ma...
#
#                            country date_added  release_year rating duration  \
# 1                    United States 2021-09-24          2021  PG-13  104 min
# 4                    United States 2021-09-20          2010  PG-13  103 min
# 5                    United States 2021-09-19          2013  PG-13   97 min
# 6     United States, India, France 2021-09-19          2013  PG-13  106 min
# 8                    United States 2021-09-16          1975     PG  124 min
# ...                            ...        ...           ...    ...      ...
# 1330                 United States 2019-01-01          2002  PG-13  124 min
# 1332                 United States 2019-01-01          2005  PG-13  101 min
# 1334                 United States 2019-09-01          2008     UR  113 min
# 1335                 United States 2019-11-20          2011      R   94 min
# 1338                 United States 2020-01-11          2006     PG   88 min
#
#       ... orig_lang     budget_x      revenue score  \
# 1     ...   English  100000000.0  369861963.8  71.0
# 4     ...   English   75000000.0  272222420.0  64.0
# 5     ...   English    3500000.0   27704111.0  63.0
# 6     ...   English   40000000.0   16340767.0  57.0
# 8     ...   English   12000000.0  482947378.0  77.0
# ...   ...       ...          ...          ...   ...
# 1330  ...   English   70000000.0  267200000.0  59.0
# 1332  ...   English   60000000.0   71073932.0  50.0
# 1334  ...   English   90000000.0  204313400.0  57.0
# 1335  ...   English   12000000.0   22750356.0  58.0
# 1338  ...   English   35000000.0   12506188.0  54.0
#
#                                                   genre  year_added  \
# 1                                                 Drama        2021
# 4                                                Comedy        2021
# 5                     Science Fiction, Thriller, Horror        2021
# 6                                       Drama, Thriller        2021
# 8                           Horror, Thriller, Adventure        2021
# ...                                                 ...         ...
# 1330                        Action, Adventure, Thriller        2019
# 1332        Action, Adventure, Crime, Mystery, Thriller        2019
# 1334                                     Comedy, Action        2019
# 1335                                      Comedy, Drama        2019
# 1338  Family, Comedy, Adventure, Action, Science Fic...        2020
#
#       month_added  release_day_gap  first_country  target_ages
# 1               9                7  United States        Teens
# 4               9             4106  United States        Teens
# 5               9             3112  United States        Teens
# 6               9             2908  United States        Teens
# 8               9            16731  United States   Older Kids
# ...           ...              ...            ...          ...
# 1330            1             5934  United States        Teens
# 1332            1             4996  United States        Teens
# 1334            9             4034  United States       Adults
# 1335           11             2862  United States       Adults
# 1338            1             4901  United States   Older Kids
#
# [944 rows x 24 columns]

# %% [markdown]
# ### Genre & Duration
#
# Untuk genre karena memang 1 film dapat masuk ke beberapa genre sekaligus sehingga kita perlu reformat saja yang tadinya kolom tersebut berbentuk string menjadi list of string untuk memudahkan pemrosesan di masa depan.
#
# Kita tambahkan 1 kolom duration_min untuk mengambil angka durasi film yang sebelumnya berbentuk string

# %%
data['genre'] = data['listed_in'].apply(lambda x : x.replace(' ,',',').replace(', ',',').split(','))
data['duration_min'] = data['duration'].str.extract('(\d+)').astype(int)

data
# Out:
#      show_id   type                          title          director  \
# 1        s10  Movie                   the starling    Theodore Melfi
# 4        s28  Movie                      grown ups      Dennis Dugan
# 5        s29  Movie                     dark skies     Scott Stewart
# 6        s30  Movie                       paranoia    Robert Luketic
# 8        s42  Movie                           jaws  Steven Spielberg
# ...      ...    ...                            ...               ...
# 1330   s8767  Movie                            xxx         Rob Cohen
# 1332   s8768  Movie        xxx: state of the union      Lee Tamahori
# 1334   s8791  Movie  you don't mess with the zohan      Dennis Dugan
# 1335   s8792  Movie                    young adult     Jason Reitman
# 1338   s8806  Movie                           zoom      Peter Hewitt
#
#                                                    cast  \
# 1     Melissa McCarthy, Chris O'Dowd, Kevin Kline, T...
# 4     Adam Sandler, Kevin James, Chris Rock, David S...
# 5     Keri Russell, Josh Hamilton, J.K. Simmons, Dak...
# 6     Liam Hemsworth, Gary Oldman, Amber Heard, Harr...
# 8     Roy Scheider, Robert Shaw, Richard Dreyfuss, L...
# ...                                                 ...
# 1330  Vin Diesel, Asia Argento, Marton Csokas, Samue...
# 1332  Ice Cube, Samuel L. Jackson, Willem Dafoe, Sco...
# 1334  Adam Sandler, John Turturro, Emmanuelle Chriqu...
# 1335  Charlize Theron, Patton Oswalt, Patrick Wilson...
# 1338  Tim Allen, Courteney Cox, Chevy Chase, Kate Ma...
#
#                            country date_added  release_year rating duration  \
# 1                    United States 2021-09-24          2021  PG-13  104 min
# 4                    United States 2021-09-20          2010  PG-13  103 min
# 5                    United States 2021-09-19          2013  PG-13   97 min
# 6     United States, India, France 2021-09-19          2013  PG-13  106 min
# 8                    United States 2021-09-16          1975     PG  124 min
# ...                            ...        ...           ...    ...      ...
# 1330                 United States 2019-01-01          2002  PG-13  124 min
# 1332                 United States 2019-01-01          2005  PG-13  101 min
# 1334                 United States 2019-09-01          2008     UR  113 min
# 1335                 United States 2019-11-20          2011      R   94 min
# 1338                 United States 2020-01-11          2006     PG   88 min
#
#       ...     budget_x      revenue score  \
# 1     ...  100000000.0  369861963.8  71.0
# 4     ...   75000000.0  272222420.0  64.0
# 5     ...    3500000.0   27704111.0  63.0
# 6     ...   40000000.0   16340767.0  57.0
# 8     ...   12000000.0  482947378.0  77.0
# ...   ...          ...          ...   ...
# 1330  ...   70000000.0  267200000.0  59.0
# 1332  ...   60000000.0   71073932.0  50.0
# 1334  ...   90000000.0  204313400.0  57.0
# 1335  ...   12000000.0   22750356.0  58.0
# 1338  ...   35000000.0   12506188.0  54.0
#
#                                              genre year_added  month_added  \
# 1                               [Comedies, Dramas]       2021            9
# 4                                       [Comedies]       2021            9
# 5                [Horror Movies, Sci-Fi & Fantasy]       2021            9
# 6                                      [Thrillers]       2021            9
# 8     [Action & Adventure, Classic Movies, Dramas]       2021            9
# ...                                            ...        ...          ...
# 1330           [Action & Adventure, Sports Movies]       2019            1
# 1332                          [Action & Adventure]       2019            1
# 1334                [Action & Adventure, Comedies]       2019            9
# 1335        [Comedies, Dramas, Independent Movies]       2019           11
# 1338          [Children & Family Movies, Comedies]       2020            1
#
#       release_day_gap  first_country target_ages  duration_min
# 1                   7  United States       Teens           104
# 4                4106  United States       Teens           103
# 5                3112  United States       Teens            97
# 6                2908  United States       Teens           106
# 8               16731  United States  Older Kids           124
# ...               ...            ...         ...           ...
# 1330             5934  United States       Teens           124
# 1332             4996  United States       Teens           101
# 1334             4034  United States      Adults           113
# 1335             2862  United States      Adults            94
# 1338             4901  United States  Older Kids            88
#
# [944 rows x 25 columns]

# %% [markdown]
# # Save Dataframe to XLSX

# %% [markdown]
# Agar data hasil pengolahan kita tidak hilang, kita backup ke xlsx agar dapat digunakan kembali sewaktu-waktu

# %%
data_backup = data

# %%
df_netflix[df_netflix['listed_in'].str.contains("LGBT", na = False)]
# Out:
# Empty DataFrame
# Columns: [show_id, type, title, director, cast, country, date_added, release_year, rating, duration, listed_in, description]
# Index: []

# %%
from google.colab import drive

# saving the excel
data_backup.to_excel("clean_netflix_imdb.xlsx", index=False)
# !cp clean_netflix_imdb.xlsx "drive/My Drive/Dataset"

# %% [markdown]
# # EDA

# %% [markdown]
# Kita akan menjawab pertanyaan-pertanyaan yang telah ditentukan di awal sesi dengan exploratory data analysis, untuk kita load data yang telah disimpan tadi

# %%
data = pd.read_excel('drive/My Drive/Dataset/clean_netflix_imdb.xlsx')
data
# Out:
#     show_id   type                          title          director  \
# 0       s10  Movie                   the starling    Theodore Melfi
# 1       s28  Movie                      grown ups      Dennis Dugan
# 2       s29  Movie                     dark skies     Scott Stewart
# 3       s30  Movie                       paranoia    Robert Luketic
# 4       s42  Movie                           jaws  Steven Spielberg
# ..      ...    ...                            ...               ...
# 939   s8767  Movie                            xxx         Rob Cohen
# 940   s8768  Movie        xxx: state of the union      Lee Tamahori
# 941   s8791  Movie  you don't mess with the zohan      Dennis Dugan
# 942   s8792  Movie                    young adult     Jason Reitman
# 943   s8806  Movie                           zoom      Peter Hewitt
#
#                                                   cast  \
# 0    Melissa McCarthy, Chris O'Dowd, Kevin Kline, T...
# 1    Adam Sandler, Kevin James, Chris Rock, David S...
# 2    Keri Russell, Josh Hamilton, J.K. Simmons, Dak...
# 3    Liam Hemsworth, Gary Oldman, Amber Heard, Harr...
# 4    Roy Scheider, Robert Shaw, Richard Dreyfuss, L...
# ..                                                 ...
# 939  Vin Diesel, Asia Argento, Marton Csokas, Samue...
# 940  Ice Cube, Samuel L. Jackson, Willem Dafoe, Sco...
# 941  Adam Sandler, John Turturro, Emmanuelle Chriqu...
# 942  Charlize Theron, Patton Oswalt, Patrick Wilson...
# 943  Tim Allen, Courteney Cox, Chevy Chase, Kate Ma...
#
#                           country date_added  release_year rating duration  \
# 0                   United States 2021-09-24          2021  PG-13  104 min
# 1                   United States 2021-09-20          2010  PG-13  103 min
# 2                   United States 2021-09-19          2013  PG-13   97 min
# 3    United States, India, France 2021-09-19          2013  PG-13  106 min
# 4                   United States 2021-09-16          1975     PG  124 min
# ..                            ...        ...           ...    ...      ...
# 939                 United States 2019-01-01          2002  PG-13  124 min
# 940                 United States 2019-01-01          2005  PG-13  101 min
# 941                 United States 2019-09-01          2008     UR  113 min
# 942                 United States 2019-11-20          2011      R   94 min
# 943                 United States 2020-01-11          2006     PG   88 min
#
#      ...     budget_x      revenue score  \
# 0    ...  100000000.0  369861963.8    71
# 1    ...   75000000.0  272222420.0    64
# 2    ...    3500000.0   27704111.0    63
# 3    ...   40000000.0   16340767.0    57
# 4    ...   12000000.0  482947378.0    77
# ..   ...          ...          ...   ...
# 939  ...   70000000.0  267200000.0    59
# 940  ...   60000000.0   71073932.0    50
# 941  ...   90000000.0  204313400.0    57
# 942  ...   12000000.0   22750356.0    58
# 943  ...   35000000.0   12506188.0    54
#
#                                                  genre year_added  \
# 0                               ['Comedies', 'Dramas']       2021
# 1                                         ['Comedies']       2021
# 2                ['Horror Movies', 'Sci-Fi & Fantasy']       2021
# 3                                        ['Thrillers']       2021
# 4    ['Action & Adventure', 'Classic Movies', 'Dram...       2021
# ..                                                 ...        ...
# 939            ['Action & Adventure', 'Sports Movies']       2019
# 940                             ['Action & Adventure']       2019
# 941                 ['Action & Adventure', 'Comedies']       2019
# 942       ['Comedies', 'Dramas', 'Independent Movies']       2019
# 943           ['Children & Family Movies', 'Comedies']       2020
#
#      month_added  release_day_gap  first_country target_ages  duration_min
# 0              9                7  United States       Teens           104
# 1              9             4106  United States       Teens           103
# 2              9             3112  United States       Teens            97
# 3              9             2908  United States       Teens           106
# 4              9            16731  United States  Older Kids           124
# ..           ...              ...            ...         ...           ...
# 939            1             5934  United States       Teens           124
# 940            1             4996  United States       Teens           101
# 941            9             4034  United States      Adults           113
# 942           11             2862  United States      Adults            94
# 943            1             4901  United States  Older Kids            88
#
# [944 rows x 25 columns]

# %%
# konversi kolom ke datetime
data['date_added'] = pd.to_datetime(data['date_added'])
data['date_x'] = pd.to_datetime(data['date_x'])

# tambahan kolom
data['year_added'] = data['date_added'].dt.year.astype(int)
data['month_added'] = data['date_added'].dt.month.astype(int)

data
# Out:
#     show_id   type                          title          director  \
# 0       s10  Movie                   the starling    Theodore Melfi
# 1       s28  Movie                      grown ups      Dennis Dugan
# 2       s29  Movie                     dark skies     Scott Stewart
# 3       s30  Movie                       paranoia    Robert Luketic
# 4       s42  Movie                           jaws  Steven Spielberg
# ..      ...    ...                            ...               ...
# 939   s8767  Movie                            xxx         Rob Cohen
# 940   s8768  Movie        xxx: state of the union      Lee Tamahori
# 941   s8791  Movie  you don't mess with the zohan      Dennis Dugan
# 942   s8792  Movie                    young adult     Jason Reitman
# 943   s8806  Movie                           zoom      Peter Hewitt
#
#                                                   cast  \
# 0    Melissa McCarthy, Chris O'Dowd, Kevin Kline, T...
# 1    Adam Sandler, Kevin James, Chris Rock, David S...
# 2    Keri Russell, Josh Hamilton, J.K. Simmons, Dak...
# 3    Liam Hemsworth, Gary Oldman, Amber Heard, Harr...
# 4    Roy Scheider, Robert Shaw, Richard Dreyfuss, L...
# ..                                                 ...
# 939  Vin Diesel, Asia Argento, Marton Csokas, Samue...
# 940  Ice Cube, Samuel L. Jackson, Willem Dafoe, Sco...
# 941  Adam Sandler, John Turturro, Emmanuelle Chriqu...
# 942  Charlize Theron, Patton Oswalt, Patrick Wilson...
# 943  Tim Allen, Courteney Cox, Chevy Chase, Kate Ma...
#
#                           country date_added  release_year rating duration  \
# 0                   United States 2021-09-24          2021  PG-13  104 min
# 1                   United States 2021-09-20          2010  PG-13  103 min
# 2                   United States 2021-09-19          2013  PG-13   97 min
# 3    United States, India, France 2021-09-19          2013  PG-13  106 min
# 4                   United States 2021-09-16          1975     PG  124 min
# ..                            ...        ...           ...    ...      ...
# 939                 United States 2019-01-01          2002  PG-13  124 min
# 940                 United States 2019-01-01          2005  PG-13  101 min
# 941                 United States 2019-09-01          2008     UR  113 min
# 942                 United States 2019-11-20          2011      R   94 min
# 943                 United States 2020-01-11          2006     PG   88 min
#
#      ...     budget_x      revenue score  \
# 0    ...  100000000.0  369861963.8    71
# 1    ...   75000000.0  272222420.0    64
# 2    ...    3500000.0   27704111.0    63
# 3    ...   40000000.0   16340767.0    57
# 4    ...   12000000.0  482947378.0    77
# ..   ...          ...          ...   ...
# 939  ...   70000000.0  267200000.0    59
# 940  ...   60000000.0   71073932.0    50
# 941  ...   90000000.0  204313400.0    57
# 942  ...   12000000.0   22750356.0    58
# 943  ...   35000000.0   12506188.0    54
#
#                                                  genre year_added  \
# 0                               ['Comedies', 'Dramas']       2021
# 1                                         ['Comedies']       2021
# 2                ['Horror Movies', 'Sci-Fi & Fantasy']       2021
# 3                                        ['Thrillers']       2021
# 4    ['Action & Adventure', 'Classic Movies', 'Dram...       2021
# ..                                                 ...        ...
# 939            ['Action & Adventure', 'Sports Movies']       2019
# 940                             ['Action & Adventure']       2019
# 941                 ['Action & Adventure', 'Comedies']       2019
# 942       ['Comedies', 'Dramas', 'Independent Movies']       2019
# 943           ['Children & Family Movies', 'Comedies']       2020
#
#      month_added  release_day_gap  first_country target_ages  duration_min
# 0              9                7  United States       Teens           104
# 1              9             4106  United States       Teens           103
# 2              9             3112  United States       Teens            97
# 3              9             2908  United States       Teens           106
# 4              9            16731  United States  Older Kids           124
# ..           ...              ...            ...         ...           ...
# 939            1             5934  United States       Teens           124
# 940            1             4996  United States       Teens           101
# 941            9             4034  United States      Adults           113
# 942           11             2862  United States      Adults            94
# 943            1             4901  United States  Older Kids            88
#
# [944 rows x 25 columns]

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 944 entries, 0 to 943
# Data columns (total 25 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   show_id          944 non-null    object
#  1   type             944 non-null    object
#  2   title            944 non-null    object
#  3   director         944 non-null    object
#  4   cast             944 non-null    object
#  5   country          944 non-null    object
#  6   date_added       944 non-null    datetime64[ns]
#  7   release_year     944 non-null    int64
#  8   rating           944 non-null    object
#  9   duration         944 non-null    object
#  10  listed_in        944 non-null    object
#  11  description      944 non-null    object
#  12  date_x           944 non-null    datetime64[ns]
#  13  crew             944 non-null    object
#  14  orig_lang        944 non-null    object
#  15  budget_x         944 non-null    float64
#  16  revenue          944 non-null    float64
#  17  score            944 non-null    int64
#  18  genre            944 non-null    object
#  19  year_added       944 non-null    int64
#  20  month_added      944 non-null    int64
#  21  release_day_gap  944 non-null    int64
#  22  first_country    944 non-null    object
#  23  target_ages      944 non-null    object
#  24  duration_min     944 non-null    int64
# dtypes: datetime64[ns](2), float64(2), int64(6), object(15)
# memory usage: 184.5+ KB

# %% [markdown]
# ## Color Palette

# %%
# Membuat palet warna untuk chart-chart yang akan dibuat
sns.palplot(['#221f1f', '#b20710', '#e50914','#f5f5f1'])

plt.title("Netflix brand palette ",loc='left',fontsize=15,y=1.2)
plt.show()

# %% [markdown]
# ## Film
#
# Di sini kita akan mulai dengan melihat film apa yang paling populer, mahal, dan disukai oleh pemirsa

# %% [markdown]
# ### Film Terpopuler
#
# Untuk mengetahui film terpopuler maka kita dapat menggunakan pendekatan dari kolom 'revenue', karena secara logika semakin banyak pendapatan maka semakin tinggi popularitasnya

# %%
data[['title', 'revenue']].sort_values(['revenue'], ascending = False).set_index('title')['revenue'][:20]
# Out:
# title
# avengers: infinity war                                2.048360e+09
# black panther                                         1.336494e+09
# doom: annihilation                                    1.168753e+09
# vivo                                                  1.139732e+09
# como caído del cielo                                  1.135762e+09
# the lord of the rings: the return of the king         1.121387e+09
# feel the beat                                         1.079234e+09
# david attenborough: a life on our planet              1.075683e+09
# the last thing he wanted                              1.052163e+09
# america: the motion picture                           1.039634e+09
# hey arnold! the jungle movie                          9.457198e+08
# the lord of the rings: the two towers                 9.191488e+08
# spider-man 3                                          8.948602e+08
# the dig                                               8.876688e+08
# alien warfare                                         8.586376e+08
# thor: ragnarok                                        8.504828e+08
# scooby-doo on zombie island                           8.344699e+08
# house of the witch                                    8.302153e+08
# indiana jones and the kingdom of the crystal skull    7.866354e+08
# the willoughbys                                       7.846450e+08
# Name: revenue, dtype: float64

# %%
color_map = ['#f5f5f1' for _ in range(20)]
color_map[0] =  '#b20710' # color highlight

labels = data[['title', 'revenue']].sort_values(['revenue'], ascending = False).set_index('title')['revenue'][:20]

ax = labels.plot(kind='bar', figsize=(18, 6), rot = 90, color = color_map)

ax.set_title('Top 20 Movies', fontsize = 15)
ax.set_xlabel("Movie", fontsize=12)
ax.set_ylabel("Revenue (USD)", fontsize=12)

rects = ax.patches

for rect, label in zip(rects, labels):
    height = rect.get_height()
    ax.text(rect.get_x() + rect.get_width() / 2, height + 10, label,
            ha='center', va='bottom')

plt.show()

# %% [markdown]
# Menggunakan matplotlib untuk memvisualisasikan label pada tiap bar cukup rumit karena harus menambahkan sendiri loop nilai sumbu y ke masing-masing sumbu x, kita coba buat bar chart menggunakan seaborn

# %%
color_map = ['#f5f5f1' for _ in range(20)]
color_map[0] =  '#b20710' # color highlight

# Set your custom color palette
sns.set_palette(sns.color_palette(color_map))

labels = data[['title', 'revenue']].sort_values(['revenue'], ascending = False)[:20]

ax = sns.barplot(labels,
             y = "revenue",
             x = "title"
            )

plt.xticks(rotation = 90)

ax.figure.set_size_inches(18,4)
ax.set_title('Top 20 Movies', fontsize = 15)
ax.set_xlabel("Movie", fontsize=12)
ax.set_ylabel("Revenue (USD)", fontsize=12)

# rects = ax.patches

# for rect, label in zip(rects, labels):
#     height = rect.get_height()
#     ax.text(rect.get_x() + rect.get_width() / 2, height + 10, label,
#             ha='center', va='bottom')

plt.show()

# %% [markdown]
# dan ternyata sama rumitnya, karena seaborn pada dasarnya seaborn dibangun atas dasar modul dari matplotlib sehingga keduanya dapat jalan berdampingan dalam satu fungsi. Kita coba menggunakan plotly

# %%
fig = px.bar(data[['title', 'revenue']].sort_values(['revenue'], ascending = False)[:20],
             y = "revenue",
             x = "title",
             text_auto='.s',
             title = 'Top 20 Movies by Revenue',
             color = "title",
             color_discrete_sequence = ['#b20710'] + ['#f5f5f1'] * 19,
             height=700
             )

fig.update_traces(textfont_size=12, textangle=0, textposition="outside", cliponaxis=False)
fig.update_layout(xaxis_tickangle = 270, showlegend=False, title_x=0.5)

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="8f194d63-474b-4998-bf26-ff56bb55d078" class="plotly-graph-div" style="height:700px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("8f194d63-474b-4998-bf26-ff56bb55d078")) {                    Plotly.newPlot(                        "8f194d63-474b-4998-bf26-ff56bb55d078",                        [{"alignmentgroup":"True","hovertemplate":"title=%{x}\u003cbr\u003erevenue=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"avengers: infinity war","marker":{"color":"#b20710","pattern":{"shape":""}},"name":"avengers: infinity war","offsetgroup":"avengers: infinity war","orientation":"v","showlegend":true,"textposition":"outside","texttemplate":"%{y:.s}","x":["avengers: infinity war"],"xaxis":"x","y":[2048359754.0],"yaxis":"y","type":"bar","textfont":{"size":12},"cliponaxis":false,"textangle":0},{"alignmentgroup":"True","hovertemplate":"title=%{x}\u003cbr\u003erevenue=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"black panther","marker":{"color":"#f5f5f1","pattern":{"shape":""}},"name":"black panther","offsetgroup":"black panther","orientation":"v","showlegend":true,"textposition":"outside","texttemplate":"%{y:.s}","x":["black panther"],"xaxis":"x","y":[1336494320.0],"yaxis":"y","type":"bar","textfont":{"size":12},"cliponaxis":false,"textangle":0},{"alignmentgroup":"True","hovertemplate":"title=%{x}\u003cbr\u003erevenue=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"doom: annihilation","marker":{"color":"#f5f5f1","pattern":{"shape":""}},"name":"doom: annihilation","offsetgroup":"doom: annihilation","orientation":"v","showlegend":true,"textposition":"outside","texttemplate":"%{y:.s}","x":["doom: annihilation"],"xaxis":"x","y":[1168752661.8],"yaxis":"y","type":"bar","textfont":{"size":12},"cliponaxis":false,"textangle":0},{"alignmentgroup":"True","hovertemplate":"title=%{x}\u003cbr\u003erevenue=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"vivo","marker":{"color":"#f5f5f1","pattern":{"shape":""}},"name":"vivo","offsetgroup":"vivo","orientation":"v","showlegend":true,"textposition":"outside","texttemplate":"%{y:.s}","x":["vivo"],"xaxis":"x","y":[1139731798.4],"yaxis":"y","type":"bar","textfont":{"size":12},"cliponaxis":false,"textangle":0},{"alignmentgroup":"True","hovertemplate":"title=%{x}\u003cbr\u003erevenue=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"como ca\u00eddo del cielo","marker":{"color":"#f5f5f1","pattern":{"shape":""}},"name":"como ca\u00eddo del cielo","offsetgroup":"como ca\u00eddo del cielo","orientation":"v","showlegend":true,"textposition":"outside","texttemplate":"%{y:.s}","x":["como ca\u00eddo del cielo"],"xaxis":"x","y":[1135762456.4],"yaxis":"y","type":"bar","textfont":{"size":12},"cliponaxis":false,"textangle":0},{"alignmentgroup":"True","hovertemplate":"title=%{x}\u003cbr\u003erevenue=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"the lord of the rings: the return of the king","marker":{"color":"#f5f5f1","pattern":{"shape":""}},"name":"the lord of the rings: the return of the king","offsetgroup":"the lord of the rings: the return of the king","orientation":"v","showlegend":true,"textposition":"outside","texttemplate":"%{y:.s}","x":["the lord of the rings: the return of the king"],"xaxis":"x","y":[1121386981.0],"yaxis":"y","type":"bar","textfont":{"size":12},"cliponaxis":false,"textangle":0},{"alignmentgroup":"True","hovertemplate":"title=%{x}\u003cbr\u003erevenue=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"feel the beat","marker":{"color":"#f5f5f1","pattern":{"shape":""}},"name":"feel the beat","offsetgroup":"feel the beat","orientation":"v","showlegend":true,"textposition":"outside","texttemplate":"%{y:.s}","x":["feel the beat"],"xaxis":"x","y":[1079 ...

# %% [markdown]
# Ternyata menggunakan plotly lebih ringkas dalam penulisan code serta plot yang interaktif menjadi lebih menarik

# %% [markdown]
# Kita lihat film paling populer yang ada di netflix adalah infinity war, menariknya film ini ternyata tidak ekslusif hanya untuk platform streaming rivalnya yaitu disney + akan tetapi pernah muncul di netflix pula.

# %% [markdown]
# ### Film Skor Tertinggi
#
# Kita lihat film terbaik berdasarkan skor imdb

# %%
fig = px.bar(data[['title', 'score']].sort_values(['score'], ascending = False)[:20],
             y = "score",
             x = "title",
             text_auto='.s',
             title = 'Top 20 Movies by Score',
             color = "title",
             color_discrete_sequence = ['#b20710'] + ['#f5f5f1'] * 19,
             height=700
             )

fig.update_traces(textfont_size=12, textangle=0, textposition="outside", cliponaxis=False)
fig.update_layout(xaxis_tickangle = 270, showlegend=False, title_x=0.5)

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="043063b0-4512-4818-8fc1-98dee78b9634" class="plotly-graph-div" style="height:700px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("043063b0-4512-4818-8fc1-98dee78b9634")) {                    Plotly.newPlot(                        "043063b0-4512-4818-8fc1-98dee78b9634",                        [{"alignmentgroup":"True","hovertemplate":"title=%{x}\u003cbr\u003escore=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"schindler's list","marker":{"color":"#b20710","pattern":{"shape":""}},"name":"schindler's list","offsetgroup":"schindler's list","orientation":"v","showlegend":true,"textposition":"outside","texttemplate":"%{y:.s}","x":["schindler's list"],"xaxis":"x","y":[86],"yaxis":"y","type":"bar","textfont":{"size":12},"cliponaxis":false,"textangle":0},{"alignmentgroup":"True","hovertemplate":"title=%{x}\u003cbr\u003escore=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"david attenborough: a life on our planet","marker":{"color":"#f5f5f1","pattern":{"shape":""}},"name":"david attenborough: a life on our planet","offsetgroup":"david attenborough: a life on our planet","orientation":"v","showlegend":true,"textposition":"outside","texttemplate":"%{y:.s}","x":["david attenborough: a life on our planet"],"xaxis":"x","y":[85],"yaxis":"y","type":"bar","textfont":{"size":12},"cliponaxis":false,"textangle":0},{"alignmentgroup":"True","hovertemplate":"title=%{x}\u003cbr\u003escore=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"pulp fiction","marker":{"color":"#f5f5f1","pattern":{"shape":""}},"name":"pulp fiction","offsetgroup":"pulp fiction","orientation":"v","showlegend":true,"textposition":"outside","texttemplate":"%{y:.s}","x":["pulp fiction"],"xaxis":"x","y":[85],"yaxis":"y","type":"bar","textfont":{"size":12},"cliponaxis":false,"textangle":0},{"alignmentgroup":"True","hovertemplate":"title=%{x}\u003cbr\u003escore=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"the lord of the rings: the return of the king","marker":{"color":"#f5f5f1","pattern":{"shape":""}},"name":"the lord of the rings: the return of the king","offsetgroup":"the lord of the rings: the return of the king","orientation":"v","showlegend":true,"textposition":"outside","texttemplate":"%{y:.s}","x":["the lord of the rings: the return of the king"],"xaxis":"x","y":[85],"yaxis":"y","type":"bar","textfont":{"size":12},"cliponaxis":false,"textangle":0},{"alignmentgroup":"True","hovertemplate":"title=%{x}\u003cbr\u003escore=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"the pianist","marker":{"color":"#f5f5f1","pattern":{"shape":""}},"name":"the pianist","offsetgroup":"the pianist","orientation":"v","showlegend":true,"textposition":"outside","texttemplate":"%{y:.s}","x":["the pianist"],"xaxis":"x","y":[84],"yaxis":"y","type":"bar","textfont":{"size":12},"cliponaxis":false,"textangle":0},{"alignmentgroup":"True","hovertemplate":"title=%{x}\u003cbr\u003escore=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"american history x","marker":{"color":"#f5f5f1","pattern":{"shape":""}},"name":"american history x","offsetgroup":"american history x","orientation":"v","showlegend":true,"textposition":"outside","texttemplate":"%{y:.s}","x":["american history x"],"xaxis":"x","y":[84],"yaxis":"y","type":"bar","textfont":{"size":12},"cliponaxis":false,"textangle":0},{"alignmentgroup":"True","hovertemplate":"title=%{x}\u003cbr\u003escore=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"one direction: this is us","marker":{"color":"#f5f5f1","pattern":{"shape":""}},"name":"one direction: this is us","offsetgroup":"one direction: this is us","orientation":"v","showlegend":true,"textposition":"outside","texttemplate":"%{y:.s}","x":["one direction:  ...

# %% [markdown]
# Dari skor IMDb, film terbaik adalah Schindler's list, jika kita lihat Avengers: Infinity War meskipun meraih pendapatan tertinggi atau bisa dibilang film terpopuler ternyata hanya meraih peringkat ke 13

# %% [markdown]
# ### Film Termahal
#
# Selanjutnya kita lihat film termahal berdasarkan budget yang dikeluarkan

# %%
fig = px.bar(data[['title', 'budget_x']].sort_values(['budget_x'], ascending = False)[:20],
             y = 'budget_x',
             x = "title",
             text_auto='.s',
             title = 'Top 20 Most Expensive Movies',
             color = "title",
             color_discrete_sequence = ['#b20710'] + ['#f5f5f1'] * 19,
             height=700
             )

fig.update_traces(textfont_size=12, textangle=0, textposition="outside", cliponaxis=False)
fig.update_layout(xaxis_tickangle = 270, showlegend=False, title_x=0.5)

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="ea6d3525-f68f-4cb4-a1bc-9fdeb69ea802" class="plotly-graph-div" style="height:700px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("ea6d3525-f68f-4cb4-a1bc-9fdeb69ea802")) {                    Plotly.newPlot(                        "ea6d3525-f68f-4cb4-a1bc-9fdeb69ea802",                        [{"alignmentgroup":"True","hovertemplate":"title=%{x}\u003cbr\u003ebudget_x=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"avengers: infinity war","marker":{"color":"#b20710","pattern":{"shape":""}},"name":"avengers: infinity war","offsetgroup":"avengers: infinity war","orientation":"v","showlegend":true,"textposition":"outside","texttemplate":"%{y:.s}","x":["avengers: infinity war"],"xaxis":"x","y":[300000000.0],"yaxis":"y","type":"bar","textfont":{"size":12},"cliponaxis":false,"textangle":0},{"alignmentgroup":"True","hovertemplate":"title=%{x}\u003cbr\u003ebudget_x=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"solo: a star wars story","marker":{"color":"#f5f5f1","pattern":{"shape":""}},"name":"solo: a star wars story","offsetgroup":"solo: a star wars story","orientation":"v","showlegend":true,"textposition":"outside","texttemplate":"%{y:.s}","x":["solo: a star wars story"],"xaxis":"x","y":[275000000.0],"yaxis":"y","type":"bar","textfont":{"size":12},"cliponaxis":false,"textangle":0},{"alignmentgroup":"True","hovertemplate":"title=%{x}\u003cbr\u003ebudget_x=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"john carter","marker":{"color":"#f5f5f1","pattern":{"shape":""}},"name":"john carter","offsetgroup":"john carter","orientation":"v","showlegend":true,"textposition":"outside","texttemplate":"%{y:.s}","x":["john carter"],"xaxis":"x","y":[263700000.0],"yaxis":"y","type":"bar","textfont":{"size":12},"cliponaxis":false,"textangle":0},{"alignmentgroup":"True","hovertemplate":"title=%{x}\u003cbr\u003ebudget_x=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"spider-man 3","marker":{"color":"#f5f5f1","pattern":{"shape":""}},"name":"spider-man 3","offsetgroup":"spider-man 3","orientation":"v","showlegend":true,"textposition":"outside","texttemplate":"%{y:.s}","x":["spider-man 3"],"xaxis":"x","y":[258000000.0],"yaxis":"y","type":"bar","textfont":{"size":12},"cliponaxis":false,"textangle":0},{"alignmentgroup":"True","hovertemplate":"title=%{x}\u003cbr\u003ebudget_x=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"superman returns","marker":{"color":"#f5f5f1","pattern":{"shape":""}},"name":"superman returns","offsetgroup":"superman returns","orientation":"v","showlegend":true,"textposition":"outside","texttemplate":"%{y:.s}","x":["superman returns"],"xaxis":"x","y":[232000000.0],"yaxis":"y","type":"bar","textfont":{"size":12},"cliponaxis":false,"textangle":0},{"alignmentgroup":"True","hovertemplate":"title=%{x}\u003cbr\u003ebudget_x=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"quantum of solace","marker":{"color":"#f5f5f1","pattern":{"shape":""}},"name":"quantum of solace","offsetgroup":"quantum of solace","orientation":"v","showlegend":true,"textposition":"outside","texttemplate":"%{y:.s}","x":["quantum of solace"],"xaxis":"x","y":[230000000.0],"yaxis":"y","type":"bar","textfont":{"size":12},"cliponaxis":false,"textangle":0},{"alignmentgroup":"True","hovertemplate":"title=%{x}\u003cbr\u003ebudget_x=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"backcountry","marker":{"color":"#f5f5f1","pattern":{"shape":""}},"name":"backcountry","offsetgroup":"backcountry","orientation":"v","showlegend":true,"textposition":"outside","texttemplate":"%{y:.s}","x":["backcountry"],"xaxis":"x","y":[213000000.0],"yaxis":"y","type":"bar","textfont":{"size":12},"cliponaxis":false,"textangle":0},{"alignmentgroup":"T ...

# %% [markdown]
# Film termahal adalah Avengers: Infinity War, jika dilihat dari popularitasnya maka budget yang dihasilkan ini selangkah memberikan hasil yang baik untuk film tersebut, lantas seberapa menguntungkan film ini?

# %% [markdown]
# ### Film paling menguntungkan

# %% [markdown]
# Jika kita lihat budget film yang sangat besar perlu dipikirkan aspek bisnis dari hasil produksinya. Oleh karena itu kita hitung keuntungan yang dihasilkan dari film tersebut dengan cara menghitung selisih 'revenue' dengan 'budget_x'

# %%
data['profit'] = data['revenue'] - data['budget_x']

# %%
fig = px.bar(data[['title', 'profit']].sort_values(['profit'], ascending = False)[:20],
             y = 'profit',
             x = "title",
             text_auto='.s',
             title = 'Top 20 Most Profitable Movies',
             color = "title",
             color_discrete_sequence = ['#b20710'] + ['#f5f5f1'] * 19,
             height=700
             )

fig.update_traces(textfont_size=12, textangle=0, textposition="outside", cliponaxis=False)
fig.update_layout(xaxis_tickangle = 270, showlegend=False, title_x=0.5)

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="81ad3d4a-6bd7-459a-b1ab-b4180e2046c3" class="plotly-graph-div" style="height:700px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("81ad3d4a-6bd7-459a-b1ab-b4180e2046c3")) {                    Plotly.newPlot(                        "81ad3d4a-6bd7-459a-b1ab-b4180e2046c3",                        [{"alignmentgroup":"True","hovertemplate":"title=%{x}\u003cbr\u003eprofit=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"avengers: infinity war","marker":{"color":"#b20710","pattern":{"shape":""}},"name":"avengers: infinity war","offsetgroup":"avengers: infinity war","orientation":"v","showlegend":true,"textposition":"outside","texttemplate":"%{y:.s}","x":["avengers: infinity war"],"xaxis":"x","y":[1748359754.0],"yaxis":"y","type":"bar","textfont":{"size":12},"cliponaxis":false,"textangle":0},{"alignmentgroup":"True","hovertemplate":"title=%{x}\u003cbr\u003eprofit=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"black panther","marker":{"color":"#f5f5f1","pattern":{"shape":""}},"name":"black panther","offsetgroup":"black panther","orientation":"v","showlegend":true,"textposition":"outside","texttemplate":"%{y:.s}","x":["black panther"],"xaxis":"x","y":[1136494320.0],"yaxis":"y","type":"bar","textfont":{"size":12},"cliponaxis":false,"textangle":0},{"alignmentgroup":"True","hovertemplate":"title=%{x}\u003cbr\u003eprofit=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"doom: annihilation","marker":{"color":"#f5f5f1","pattern":{"shape":""}},"name":"doom: annihilation","offsetgroup":"doom: annihilation","orientation":"v","showlegend":true,"textposition":"outside","texttemplate":"%{y:.s}","x":["doom: annihilation"],"xaxis":"x","y":[1048552661.8],"yaxis":"y","type":"bar","textfont":{"size":12},"cliponaxis":false,"textangle":0},{"alignmentgroup":"True","hovertemplate":"title=%{x}\u003cbr\u003eprofit=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"the lord of the rings: the return of the king","marker":{"color":"#f5f5f1","pattern":{"shape":""}},"name":"the lord of the rings: the return of the king","offsetgroup":"the lord of the rings: the return of the king","orientation":"v","showlegend":true,"textposition":"outside","texttemplate":"%{y:.s}","x":["the lord of the rings: the return of the king"],"xaxis":"x","y":[1027386981.0],"yaxis":"y","type":"bar","textfont":{"size":12},"cliponaxis":false,"textangle":0},{"alignmentgroup":"True","hovertemplate":"title=%{x}\u003cbr\u003eprofit=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"vivo","marker":{"color":"#f5f5f1","pattern":{"shape":""}},"name":"vivo","offsetgroup":"vivo","orientation":"v","showlegend":true,"textposition":"outside","texttemplate":"%{y:.s}","x":["vivo"],"xaxis":"x","y":[1014731798.4000001],"yaxis":"y","type":"bar","textfont":{"size":12},"cliponaxis":false,"textangle":0},{"alignmentgroup":"True","hovertemplate":"title=%{x}\u003cbr\u003eprofit=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"feel the beat","marker":{"color":"#f5f5f1","pattern":{"shape":""}},"name":"feel the beat","offsetgroup":"feel the beat","orientation":"v","showlegend":true,"textposition":"outside","texttemplate":"%{y:.s}","x":["feel the beat"],"xaxis":"x","y":[1005834048.0],"yaxis":"y","type":"bar","textfont":{"size":12},"cliponaxis":false,"textangle":0},{"alignmentgroup":"True","hovertemplate":"title=%{x}\u003cbr\u003eprofit=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"como ca\u00eddo del cielo","marker":{"color":"#f5f5f1","pattern":{"shape":""}},"name":"como ca\u00eddo del cielo","offsetgroup":"como ca\u00eddo del cielo","orientation":"v","showlegend":true,"textposition":"outside","texttemplate":"%{y:.s}","x":["como ca\u00eddo del cielo"],"xaxis":"x","y":[99176 ...

# %% [markdown]
# ## Target Market
#
# Target market dapat dilihat dari genre film yang tersedia dan juga demografi yang dituju

# %% [markdown]
# ### Genre Terbanyak

# %% [markdown]
# Kita ingin melihat jenis konten seperti apa yang tersedia di netflix

# %%
data['genre'].value_counts()
# Out:
# ['Action & Adventure']                                              82
# ['Children & Family Movies', 'Comedies']                            70
# ['Action & Adventure', 'Sci-Fi & Fantasy']                          46
# ['Comedies', 'Romantic Movies']                                     40
# ['Dramas']                                                          39
#                                                                     ..
# ['Classic Movies', 'Music & Musicals']                               1
# ['Independent Movies', 'Thrillers']                                  1
# ['Children & Family Movies', 'Comedies', 'Faith & Spirituality']     1
# ['Dramas', 'International Movies', 'Music & Musicals']               1
# ['Action & Adventure', 'Sports Movies']                              1
# Name: genre, Length: 152, dtype: int64

# %%
# Menggunakan apply dan lambda untuk mengonversi string menjadi list
data['genre'] = data['genre'].apply(lambda x: eval(x) if isinstance(x, str) else x)

data['genre']
# Out:
# 0                                [Comedies, Dramas]
# 1                                        [Comedies]
# 2                 [Horror Movies, Sci-Fi & Fantasy]
# 3                                       [Thrillers]
# 4      [Action & Adventure, Classic Movies, Dramas]
#                            ...
# 939             [Action & Adventure, Sports Movies]
# 940                            [Action & Adventure]
# 941                  [Action & Adventure, Comedies]
# 942          [Comedies, Dramas, Independent Movies]
# 943            [Children & Family Movies, Comedies]
# Name: genre, Length: 944, dtype: object

# %%
# mengeluarkan isi dalam list untuk menjadi dataframe genre
genres = pd.DataFrame([(index, value) for (index, values) in
                      data['genre'].iteritems() for value in values],
                     columns=['kolom', 'genre']).drop('kolom', axis = 1)

genres
# Out:
#                          genre
# 0                     Comedies
# 1                       Dramas
# 2                     Comedies
# 3                Horror Movies
# 4             Sci-Fi & Fantasy
# ...                        ...
# 1913                  Comedies
# 1914                    Dramas
# 1915        Independent Movies
# 1916  Children & Family Movies
# 1917                  Comedies
#
# [1918 rows x 1 columns]

# %%
# grouping genre baru
genre_group = genres.groupby('genre')['genre'].count().reset_index(name='counts')

genre_group
# Out:
#                        genre  counts
# 0         Action & Adventure     288
# 1   Children & Family Movies     160
# 2             Classic Movies      53
# 3                   Comedies     305
# 4                Cult Movies      39
# 5              Documentaries      12
# 6                     Dramas     334
# 7       Faith & Spirituality      17
# 8              Horror Movies      96
# 9         Independent Movies     103
# 10      International Movies      80
# 11          Music & Musicals      30
# 12           Romantic Movies     105
# 13          Sci-Fi & Fantasy     122
# 14             Sports Movies      28
# 15                 Thrillers     146

# %%
# Menggunakan apply dan lambda untuk mengonversi string menjadi list
data['genre'] = data['genre'].apply(lambda x: eval(x) if isinstance(x, str) else x)

# mengeluarkan isi dalam list untuk menjadi dataframe genre
genres = pd.DataFrame([(index, value) for (index, values) in
                      data['genre'].iteritems() for value in values],
                     columns=['kolom', 'genre']).drop('kolom', axis = 1)

# grouping genre baru
genre_group = genres.groupby('genre')['genre'].count().reset_index(name='counts')

genre_group
# Out:
#                        genre  counts
# 0         Action & Adventure     288
# 1   Children & Family Movies     160
# 2             Classic Movies      53
# 3                   Comedies     305
# 4                Cult Movies      39
# 5              Documentaries      12
# 6                     Dramas     334
# 7       Faith & Spirituality      17
# 8              Horror Movies      96
# 9         Independent Movies     103
# 10      International Movies      80
# 11          Music & Musicals      30
# 12           Romantic Movies     105
# 13          Sci-Fi & Fantasy     122
# 14             Sports Movies      28
# 15                 Thrillers     146

# %% [markdown]
# Simpan genre groupby ke xlsx file

# %%
# saving the excel
genre_group.to_excel("genre_group.xlsx", index=False)
# !cp genre_group.xlsx "drive/My Drive/Dataset"

# %%
fig = px.pie(genre_group,
             values = genre_group.counts,
             names = genre_group.genre,
             color = genre_group.genre,
             )
fig
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="22c76547-8c3c-4994-a06f-0990cd5b01b2" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("22c76547-8c3c-4994-a06f-0990cd5b01b2")) {                    Plotly.newPlot(                        "22c76547-8c3c-4994-a06f-0990cd5b01b2",                        [{"customdata":[["Action & Adventure"],["Children & Family Movies"],["Classic Movies"],["Comedies"],["Cult Movies"],["Documentaries"],["Dramas"],["Faith & Spirituality"],["Horror Movies"],["Independent Movies"],["International Movies"],["Music & Musicals"],["Romantic Movies"],["Sci-Fi & Fantasy"],["Sports Movies"],["Thrillers"]],"domain":{"x":[0.0,1.0],"y":[0.0,1.0]},"hovertemplate":"genre=%{customdata[0]}\u003cbr\u003ecounts=%{value}\u003cextra\u003e\u003c\u002fextra\u003e","labels":["Action & Adventure","Children & Family Movies","Classic Movies","Comedies","Cult Movies","Documentaries","Dramas","Faith & Spirituality","Horror Movies","Independent Movies","International Movies","Music & Musicals","Romantic Movies","Sci-Fi & Fantasy","Sports Movies","Thrillers"],"legendgroup":"","marker":{"colors":["#636efa","#EF553B","#00cc96","#ab63fa","#FFA15A","#19d3f3","#FF6692","#B6E880","#FF97FF","#FECB52","#636efa","#EF553B","#00cc96","#ab63fa","#FFA15A","#19d3f3"]},"name":"","showlegend":true,"values":[288,160,53,305,39,12,334,17,96,103,80,30,105,122,28,146],"type":"pie"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed ...

# %% [markdown]
# Drama adalah jenis film terbanyak yang tersedia di netflix dan disusul oleh film komedi dan film aksi petualangan.
#
# Selain dalam bentuk pie chart kita dapat menampilkan analisis ini dalam bentuk wordcloud.

# %%
from wordcloud import WordCloud, STOPWORDS, ImageColorGenerator
from collections import Counter

genres_list = list(genres['genre'])

genres_l = Counter(genres_list)

wordcloud = WordCloud(max_words=1000000,background_color="white").generate_from_frequencies(genres_l)

plt.imshow(wordcloud, interpolation='bilinear')
plt.axis("off")
plt.show()

# %% [markdown]
# Fungsi utama wordcloud adalah menunjukkan kemunculan suatu kata dalam bentuk tulisan, kita coba lihat bentuk wordcloud untuk nama film

# %%
films = list(data['title'])
film = []

for i in films:
    i=list(i.split(','))
    for j in i:
        film.append(j.replace(' ',""))

film = Counter(film)

text = list(set(film))

#assigning shape to the word cloud
wordcloud = WordCloud(max_words=1000000,background_color="white").generate(str(text))

plt.imshow(wordcloud, interpolation='bilinear')
plt.axis("off")
plt.show()

# %% [markdown]
# Dari wordcloud di atas uniknya film dengan kata Barbie memiliki jumlah film terbanyak di netflix.
#
# Bagaimana dengan film di Indonesia ya?

# %%
from wordcloud import WordCloud, STOPWORDS, ImageColorGenerator
from collections import Counter

film_indonesia=list(data.loc[data['first_country'] == 'Indonesia', 'title'])
film_indo=[]

for i in film_indonesia:
    i=list(i.split(','))
    for j in i:
        film_indo.append(j.replace(' ',""))

film = Counter(film_indo)

text = list(set(film_indo))

#assigning shape to the word cloud
wordcloud = WordCloud(max_words=1000000,background_color="white").generate(str(text))

plt.imshow(wordcloud, interpolation='bilinear')
plt.axis("off")
plt.show()

# %% [markdown]
# Ternyata hanya ada 2 film Indonesia dan masing-masing hanya menggunakan 1 kata pada judul film

# %% [markdown]
# ### Demographic Target
#
# Kita lihat seperti apa distribusi demografi yang dituju oleh netflix, hal ini dapat kita lihat dari movie rating system (SU, remaja, dll).

# %%
fig = px.pie(pd.DataFrame(data['target_ages'].value_counts()),
             values = pd.DataFrame(data['target_ages'].value_counts()).target_ages,
             names = pd.DataFrame(data['target_ages'].value_counts()).index,
             color = pd.DataFrame(data['target_ages'].value_counts()).index,
             color_discrete_map = {"Adults": "#221f1f",
                                    "Teens": "#b20710",
                                    "Older Kids": "#e50914",
                                    "Kids": "#f5f5f1"
                                }
             )
fig
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="ea67cd08-ab91-4e8a-92c8-95dd720f9672" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("ea67cd08-ab91-4e8a-92c8-95dd720f9672")) {                    Plotly.newPlot(                        "ea67cd08-ab91-4e8a-92c8-95dd720f9672",                        [{"customdata":[["Adults"],["Teens"],["Older Kids"],["Kids"]],"domain":{"x":[0.0,1.0],"y":[0.0,1.0]},"hovertemplate":"label=%{label}\u003cbr\u003evalue=%{value}\u003cbr\u003ecolor=%{customdata[0]}\u003cextra\u003e\u003c\u002fextra\u003e","labels":["Adults","Teens","Older Kids","Kids"],"legendgroup":"","marker":{"colors":["#221f1f","#b20710","#e50914","#f5f5f1"]},"name":"","showlegend":true,"values":[467,281,167,29],"type":"pie"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"scattergeo":[{"type":"s ...

# %% [markdown]
# Netflix memiliki target penonton terbesar pada orang-orang dewasa, yang dimana sejalan dengan model bisnis netflix yang dimana tidak murah untuk mendaftar penggunaan layanan netflix

# %% [markdown]
# ## Country Origin

# %% [markdown]
# ### Movie Score by Country
#
# Selanjutnya kita coba analisis sebaran score film di tiap negara.
#
# Sebelum kita membuat visualisasinya, kita akan membuat dataframe group agar lebih mudah ke depannya untuk digunakan

# %%
# country_group = data.groupby(["first_country"]).agg(
#     # total_movie = ('title', 'count'),
#     # total_revenue = ('revenue', 'sum'), avg_revenue = ('revenue', 'mean'),
#     # total_budget = ('budget_x', 'sum'), avg_budget = ('budget_x', 'mean'),
#     avg_score = ('score', 'mean'),
#     # max_score = ('score', 'max')
#     ).sort_values("total_movie", ascending = False).reset_index()

# country_group

country_group = data.groupby(["first_country"]).agg(
    avg_score = ('score', 'mean'),
    ).sort_values("avg_score", ascending = False).reset_index()

country_group
# Out:
#            first_country  avg_score
# 0               Malaysia  77.000000
# 1                 Mexico  76.333333
# 2            New Zealand  76.000000
# 3                  India  72.666667
# 4                Finland  71.000000
# 5                Ireland  70.000000
# 6              Argentina  69.500000
# 7              Hong Kong  69.250000
# 8                  Spain  69.166667
# 9            South Korea  69.000000
# 10                 China  68.833333
# 11        United Kingdom  68.230000
# 12               Belgium  68.000000
# 13  United Arab Emirates  68.000000
# 14               Germany  67.750000
# 15        Czech Republic  67.000000
# 16           Switzerland  67.000000
# 17                 Italy  65.500000
# 18         United States  65.014205
# 19          South Africa  65.000000
# 20                France  64.235294
# 21           Netherlands  64.000000
# 22                Russia  64.000000
# 23               Hungary  64.000000
# 24               Denmark  64.000000
# 25             Australia  63.250000
# 26                Canada  62.444444
# 27                Poland  61.000000
# 28              Thailand  61.000000
# 29              Bulgaria  59.000000
# 30             Indonesia  59.000000
# 31               Romania  58.000000
# 32                Serbia  53.500000
# 33                Norway  43.000000

# %% [markdown]
# Kita tampilkan distribusi skor dalam bentuk heatmap pada peta

# %%
# Buat peta
fig = px.choropleth(country_group, locations='first_country', color='avg_score', locationmode='country names')
fig.update_layout(title='Average IMDb Score in every country')

# Tampilkan grafik
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="a87f20f7-cc21-4cf3-a070-42a70c4c93fb" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("a87f20f7-cc21-4cf3-a070-42a70c4c93fb")) {                    Plotly.newPlot(                        "a87f20f7-cc21-4cf3-a070-42a70c4c93fb",                        [{"coloraxis":"coloraxis","geo":"geo","hovertemplate":"first_country=%{location}\u003cbr\u003eavg_score=%{z}\u003cextra\u003e\u003c\u002fextra\u003e","locationmode":"country names","locations":["Malaysia","Mexico","New Zealand","India","Finland","Ireland","Argentina","Hong Kong","Spain","South Korea","China","United Kingdom","Belgium","United Arab Emirates","Germany","Czech Republic","Switzerland","Italy","United States","South Africa","France","Netherlands","Russia","Hungary","Denmark","Australia","Canada","Poland","Thailand","Bulgaria","Indonesia","Romania","Serbia","Norway"],"name":"","z":[77.0,76.33333333333333,76.0,72.66666666666667,71.0,70.0,69.5,69.25,69.16666666666667,69.0,68.83333333333333,68.23,68.0,68.0,67.75,67.0,67.0,65.5,65.01420454545455,65.0,64.23529411764706,64.0,64.0,64.0,64.0,63.25,62.44444444444444,61.0,61.0,59.0,59.0,58.0,53.5,43.0],"type":"choropleth"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode ...

# %% [markdown]
# Terlihat ada beberapa negara yang memiliki skor rata-rata IMDb lebih tinggi dari Hollywood atau Amerika, akan tetapi rata-rata skor ini bergantung juga dengan jumlah film di dalamnya. Oleh karena itu kita perlu melihat distribusi jumlah film di setiap negara

# %% [markdown]
# ### Movie Distribution by time
#
# Kita akan coba lihat distribusi film dari waktu ke waktu dari sisi jumlah film dan skor film

# %%
movie_year = data.groupby(["year_added"]).agg(
    total_movie = ('title', 'count'),
    total_revenue = ('revenue', 'sum'), avg_revenue = ('revenue', 'mean'),
    total_budget = ('budget_x', 'sum'), avg_budget = ('budget_x', 'mean'),
    avg_score = ('score', 'mean'),
    max_score = ('score', 'max')
    ).reset_index()

movie_year
# Out:
#    year_added  total_movie  total_revenue   avg_revenue  total_budget  \
# 0        2011            1   6.019574e+08  6.019574e+08  7.900000e+07
# 1        2013            1   6.132801e+08  6.132801e+08  1.168000e+08
# 2        2014            1   4.869911e+08  4.869911e+08  1.131600e+08
# 3        2015            3   4.106762e+08  1.368921e+08  1.886000e+08
# 4        2016           13   2.998404e+09  2.306465e+08  8.466440e+08
# 5        2017           55   1.336937e+10  2.430795e+08  3.906473e+09
# 6        2018          101   1.641204e+10  1.624954e+08  4.784128e+09
# 7        2019          247   4.852989e+10  1.964773e+08  1.429830e+10
# 8        2020          250   5.012102e+10  2.004841e+08  1.360152e+10
# 9        2021          272   5.268321e+10  1.936883e+08  1.427371e+10
#
#      avg_budget  avg_score  max_score
# 0  7.900000e+07  68.000000         68
# 1  1.168000e+08  73.000000         73
# 2  1.131600e+08  63.000000         63
# 3  6.286667e+07  63.000000         73
# 4  6.512646e+07  59.000000         72
# 5  7.102679e+07  63.181818         78
# 6  4.736761e+07  64.722772         86
# 7  5.788786e+07  65.894737         85
# 8  5.440607e+07  65.844000         85
# 9  5.247687e+07  65.834559         84

# %%
fig = px.line(movie_year,
             y = movie_year.total_movie,
             x = movie_year.year_added,
             color_discrete_sequence = ['#b20710'],
             markers=True)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="b8178c78-e72a-4a5c-9d67-ff6cd4fc533d" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("b8178c78-e72a-4a5c-9d67-ff6cd4fc533d")) {                    Plotly.newPlot(                        "b8178c78-e72a-4a5c-9d67-ff6cd4fc533d",                        [{"hovertemplate":"year_added=%{x}\u003cbr\u003etotal_movie=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","line":{"color":"#b20710","dash":"solid"},"marker":{"symbol":"circle"},"mode":"markers+lines","name":"","orientation":"v","showlegend":false,"x":[2011,2013,2014,2015,2016,2017,2018,2019,2020,2021],"xaxis":"x","y":[1,1,1,3,13,55,101,247,250,272],"yaxis":"y","type":"scatter"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"scattergeo":[{"type":"scattergeo","marker":{"colorbar":{"o ...

# %% [markdown]
# Dar dataset yang kita miliki ternyata kebanyakan penambahan film di mulai pada tahun 2016 ke atas, akan tetapi bisa jadi konten film lama yang ditambahkan di awal netflix streaming berdiri sudah tidak ada lagi. Kita lihat sebaran rata-rata skor di tiap tahunnya

# %%
fig = px.line(movie_year,
             y = movie_year.avg_score,
             x = movie_year.year_added,
             color_discrete_sequence = ['#b20710'],
             markers=True)

# fig.update_yaxes(rangemode="tozero")

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="6fc9d0fa-9080-4db1-b6d2-f9596f319642" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("6fc9d0fa-9080-4db1-b6d2-f9596f319642")) {                    Plotly.newPlot(                        "6fc9d0fa-9080-4db1-b6d2-f9596f319642",                        [{"hovertemplate":"year_added=%{x}\u003cbr\u003eavg_score=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","line":{"color":"#b20710","dash":"solid"},"marker":{"symbol":"circle"},"mode":"markers+lines","name":"","orientation":"v","showlegend":false,"x":[2011,2013,2014,2015,2016,2017,2018,2019,2020,2021],"xaxis":"x","y":[68.0,73.0,63.0,63.0,59.0,63.18181818181818,64.72277227722772,65.89473684210526,65.844,65.8345588235294],"yaxis":"y","type":"scatter"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"ty ...

# %% [markdown]
# Seiring bertambahnya jumlah film yang tersedia di 2018 - 2019 adanya kenaikan rata-rata skor dari film yang disajikan , akan tetapi 2019 hingga 2021 rata-rata skor dari film yang disajikan melandai. Kita coba bandingkan dengan max_score dengan menampilkan 2 chart sekaligus.

# %%
# Chart 1
fig1 = px.line(movie_year,
                  y="avg_score",
                  x="year_added",
                  color_discrete_sequence=['#b20710'],
                  markers=True)

# Chart 2
fig2 = px.line(movie_year,
                  y="max_score",
                  x="year_added",
                  color_discrete_sequence=['#221f1f'],
                  markers=True)


# Tampilkan chart
fig1.show()
fig2.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="6186828c-f148-4441-a975-ecda74181660" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("6186828c-f148-4441-a975-ecda74181660")) {                    Plotly.newPlot(                        "6186828c-f148-4441-a975-ecda74181660",                        [{"hovertemplate":"year_added=%{x}\u003cbr\u003eavg_score=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","line":{"color":"#b20710","dash":"solid"},"marker":{"symbol":"circle"},"mode":"markers+lines","name":"","orientation":"v","showlegend":false,"x":[2011,2013,2014,2015,2016,2017,2018,2019,2020,2021],"xaxis":"x","y":[68.0,73.0,63.0,63.0,59.0,63.18181818181818,64.72277227722772,65.89473684210526,65.844,65.8345588235294],"yaxis":"y","type":"scatter"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"ty ...
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="162900e3-d953-4f67-8505-2b9efca09dd5" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("162900e3-d953-4f67-8505-2b9efca09dd5")) {                    Plotly.newPlot(                        "162900e3-d953-4f67-8505-2b9efca09dd5",                        [{"hovertemplate":"year_added=%{x}\u003cbr\u003emax_score=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","line":{"color":"#221f1f","dash":"solid"},"marker":{"symbol":"circle"},"mode":"markers+lines","name":"","orientation":"v","showlegend":false,"x":[2011,2013,2014,2015,2016,2017,2018,2019,2020,2021],"xaxis":"x","y":[68,73,63,73,72,78,86,85,85,84],"yaxis":"y","type":"scatter"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"scattergeo":[{"type":"scattergeo","marker":{"colorbar":{"out ...

# %% [markdown]
# Cara lain untuk menampilkan, dengan penggabungan kedua line chart menggunakan graph_objects dan subplots

# %%
import plotly.graph_objects as go
from plotly.subplots import make_subplots
import plotly.express as px

# Buat subplot dengan dua baris
fig = make_subplots(rows=1, cols=1, subplot_titles=['Avg Score', 'Max Score'])

# Tambahkan line chart pertama dengan marker ke baris pertama
fig.add_trace(go.Scatter(x=movie_year.year_added.values, y=movie_year.avg_score.values, mode='lines+markers', name='avg_score', marker=dict(color='#b20710')))

# Tambahkan line chart kedua dengan marker ke baris kedua
fig.add_trace(go.Scatter(x=movie_year.year_added.values, y=movie_year.max_score.values, mode='lines+markers', name='max_score', marker=dict(color='#221f1f')))

# Atur layout subplot
fig.update_layout(title_text='IMDb Score from time to time')

# Tampilkan chart
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="41f5c199-c07b-4bd0-98b8-542bc41e0e61" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("41f5c199-c07b-4bd0-98b8-542bc41e0e61")) {                    Plotly.newPlot(                        "41f5c199-c07b-4bd0-98b8-542bc41e0e61",                        [{"marker":{"color":"#b20710"},"mode":"lines+markers","name":"avg_score","x":[2011,2013,2014,2015,2016,2017,2018,2019,2020,2021],"y":[68.0,73.0,63.0,63.0,59.0,63.18181818181818,64.72277227722772,65.89473684210526,65.844,65.8345588235294],"type":"scatter"},{"marker":{"color":"#221f1f"},"mode":"lines+markers","name":"max_score","x":[2011,2013,2014,2015,2016,2017,2018,2019,2020,2021],"y":[68,73,63,73,72,78,86,85,85,84],"type":"scatter"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"scattergeo":[{"typ ...

# %% [markdown]
# Dari grafik terlihat bahwa kualitas film meningkat seiring berjalannya waktu, akan tetapi sesuai dengan grafik avg_score, film terbaik di setiap tahunnya pun melandai bahkan cenderung sedikit menurun di tahun 2018 - 2021.

# %% [markdown]
# ### Movie Revenue by country & Month
#
# Untuk melihat sebaran film di tiap negara berdasarkan negara & waktunya, kita perlu buat groupby lagi dengan menambahkan kolom tahun dan bulan ditambahkannya konten ke netflix

# %%
country_group_year = data.groupby(["first_country", 'year_added', 'month_added']).agg(
    total_movie = ('title', 'count'),
    total_revenue = ('revenue', 'sum'), avg_revenue = ('revenue', 'mean'),
    total_budget = ('budget_x', 'sum'), avg_budget = ('budget_x', 'mean'),
    avg_score = ('score', 'mean'),
    max_score = ('score', 'max')
    ).reset_index()

country_group_year
# Out:
#      first_country  year_added  month_added  total_movie  total_revenue  \
# 0        Argentina        2018            8            1   1.002163e+08
# 1        Argentina        2021            9            1   7.813305e+08
# 2        Australia        2018            1            1   9.238269e+07
# 3        Australia        2018            7            2   2.634247e+08
# 4        Australia        2019           11            1   1.575749e+06
# ..             ...         ...          ...          ...            ...
# 227  United States        2021            5           22   3.646880e+09
# 228  United States        2021            6           26   4.537749e+09
# 229  United States        2021            7           41   7.871469e+09
# 230  United States        2021            8           25   5.616366e+09
# 231  United States        2021            9           30   4.067320e+09
#
#       avg_revenue  total_budget    avg_budget  avg_score  max_score
# 0    1.002163e+08  6.670000e+05  6.670000e+05  62.000000         62
# 1    7.813305e+08  9.240000e+07  9.240000e+07  77.000000         77
# 2    9.238269e+07  3.400000e+06  3.400000e+06  61.000000         61
# 3    1.317123e+08  1.250000e+08  6.250000e+07  63.500000         64
# 4    1.575749e+06  1.600000e+07  1.600000e+07  61.000000         61
# ..            ...           ...           ...        ...        ...
# 227  1.657673e+08  1.232000e+09  5.600000e+07  64.045455         77
# 228  1.745288e+08  1.189500e+09  4.575000e+07  63.769231         80
# 229  1.919871e+08  1.841300e+09  4.490976e+07  66.024390         82
# 230  2.246546e+08  1.283409e+09  5.133636e+07  66.440000         84
# 231  1.355773e+08  1.392920e+09  4.643067e+07  63.566667         78
#
# [232 rows x 10 columns]

# %% [markdown]
# Selain line chart, kita juga dapat membuat area chart untuk menunjukkan distribusi data. Sekarang kita coba lihat sebaran pendapatan film di tiap bulan penambahan konten dan negara-negara asal kontennya

# %%
fig = px.area(pd.DataFrame(country_group_year.groupby(['first_country', 'month_added'])[['total_revenue']].sum().reset_index()),
             y = pd.DataFrame(country_group_year.groupby(['first_country', 'month_added'])[['total_revenue']].sum().reset_index())['total_revenue'],
             x = pd.DataFrame(country_group_year.groupby(['first_country', 'month_added'])[['total_revenue']].sum().reset_index())['month_added'],
             color = pd.DataFrame(country_group_year.groupby(['first_country', 'month_added'])[['total_revenue']].sum().reset_index())['first_country'],
             labels={
                     "x": "month",
                     "y": "revenue",
                     "color": "first_country"
                },
             markers=True)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="c86c193a-176d-4006-8410-af01135236ca" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("c86c193a-176d-4006-8410-af01135236ca")) {                    Plotly.newPlot(                        "c86c193a-176d-4006-8410-af01135236ca",                        [{"fillpattern":{"shape":""},"hovertemplate":"first_country=Argentina\u003cbr\u003emonth=%{x}\u003cbr\u003erevenue=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Argentina","line":{"color":"#636efa"},"marker":{"symbol":"circle"},"mode":"markers+lines","name":"Argentina","orientation":"v","showlegend":true,"stackgroup":"1","x":[8,9],"xaxis":"x","y":[100216295.0,781330534.6],"yaxis":"y","type":"scatter"},{"fillpattern":{"shape":""},"hovertemplate":"first_country=Australia\u003cbr\u003emonth=%{x}\u003cbr\u003erevenue=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Australia","line":{"color":"#EF553B"},"marker":{"symbol":"circle"},"mode":"markers+lines","name":"Australia","orientation":"v","showlegend":true,"stackgroup":"1","x":[1,7,8,9,11,12],"xaxis":"x","y":[462244651.0,263424681.8,99750000.0,39393111.0,1575749.0,21413105.0],"yaxis":"y","type":"scatter"},{"fillpattern":{"shape":""},"hovertemplate":"first_country=Belgium\u003cbr\u003emonth=%{x}\u003cbr\u003erevenue=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Belgium","line":{"color":"#00cc96"},"marker":{"symbol":"circle"},"mode":"markers+lines","name":"Belgium","orientation":"v","showlegend":true,"stackgroup":"1","x":[5],"xaxis":"x","y":[515295729.6],"yaxis":"y","type":"scatter"},{"fillpattern":{"shape":""},"hovertemplate":"first_country=Bulgaria\u003cbr\u003emonth=%{x}\u003cbr\u003erevenue=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Bulgaria","line":{"color":"#ab63fa"},"marker":{"symbol":"circle"},"mode":"markers+lines","name":"Bulgaria","orientation":"v","showlegend":true,"stackgroup":"1","x":[1],"xaxis":"x","y":[320705.0],"yaxis":"y","type":"scatter"},{"fillpattern":{"shape":""},"hovertemplate":"first_country=Canada\u003cbr\u003emonth=%{x}\u003cbr\u003erevenue=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Canada","line":{"color":"#FFA15A"},"marker":{"symbol":"circle"},"mode":"markers+lines","name":"Canada","orientation":"v","showlegend":true,"stackgroup":"1","x":[1,2,3,4,6,7,8,9,10,11,12],"xaxis":"x","y":[378613819.8,321834351.0,478445768.8,861937863.8,838796566.8,605262155.2,1573179427.8000002,665939325.0,2341218.0,970171518.8,327632030.8],"yaxis":"y","type":"scatter"},{"fillpattern":{"shape":""},"hovertemplate":"first_country=China\u003cbr\u003emonth=%{x}\u003cbr\u003erevenue=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"China","line":{"color":"#19d3f3"},"marker":{"symbol":"circle"},"mode":"markers+lines","name":"China","orientation":"v","showlegend":true,"stackgroup":"1","x":[4,6,7,9,10],"xaxis":"x","y":[59284015.0,25860000.0,656325126.0,283819551.8,473097256.6],"yaxis":"y","type":"scatter"},{"fillpattern":{"shape":""},"hovertemplate":"first_country=Czech Republic\u003cbr\u003emonth=%{x}\u003cbr\u003erevenue=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Czech Republic","line":{"color":"#FF6692"},"marker":{"symbol":"circle"},"mode":"markers+lines","name":"Czech Republic","orientation":"v","showlegend":true,"stackgroup":"1","x":[2,4],"xaxis":"x","y":[22024849.0,26152835.0],"yaxis":"y","type":"scatter"},{"fillpattern":{"shape":""},"hovertemplate":"first_country=Denmark\u003cbr\u003emonth=%{x}\u003cbr\u003erevenue=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Denmark","line":{"color":"#B6E880"},"marker":{"symbol":"circle"},"mode":"markers+lines","name":"Denmark","orientation":"v","showlegend":true,"stackgro ...

# %% [markdown]
# Dari area chart ini kita dapat melihat bahwa film yang paling laku itu ketika dirilis ke netflix pada bulan Januari, bukan di bulan-bulan musim panas Amerika (Juli - September)

# %% [markdown]
# ## Movie Duration
#
# Selanjutnya kita lihat durasi film dalam menit yang paling banyak disajikan di netflix

# %%
fig = px.histogram(data['duration_min'], color_discrete_sequence = ['#b20710'], text_auto=True)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="e75f030b-2b3f-48eb-8c54-f2373d9f5e6f" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("e75f030b-2b3f-48eb-8c54-f2373d9f5e6f")) {                    Plotly.newPlot(                        "e75f030b-2b3f-48eb-8c54-f2373d9f5e6f",                        [{"alignmentgroup":"True","bingroup":"x","hovertemplate":"variable=duration_min\u003cbr\u003evalue=%{x}\u003cbr\u003ecount=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"duration_min","marker":{"color":"#b20710","pattern":{"shape":""}},"name":"duration_min","offsetgroup":"duration_min","orientation":"v","showlegend":true,"texttemplate":"%{value}","x":[104,103,97,106,124,116,91,115,122,106,95,95,121,142,113,154,95,120,100,82,124,114,104,101,105,102,106,118,121,229,76,95,110,121,105,94,156,112,95,114,129,107,108,90,92,110,94,121,110,114,100,115,87,88,114,142,90,105,103,116,99,148,97,112,130,105,105,118,97,102,114,92,117,165,94,105,124,131,122,122,86,95,96,97,91,90,126,115,125,94,90,95,155,98,96,94,93,120,145,126,118,109,89,106,101,123,106,128,85,108,105,133,129,127,127,113,112,130,85,124,121,89,114,98,100,97,87,111,122,119,101,102,86,97,104,110,101,101,101,104,90,109,88,132,104,99,98,101,94,99,128,127,136,97,97,97,94,94,94,148,88,109,107,107,102,105,95,118,109,95,115,93,96,138,113,121,127,89,89,93,102,101,85,116,91,116,132,126,93,60,119,123,102,127,88,137,107,88,93,98,98,91,158,164,103,96,101,173,88,149,102,83,104,111,116,98,115,113,131,118,90,81,119,112,181,134,94,119,103,134,86,116,89,139,112,89,113,95,133,127,100,108,116,85,128,111,148,104,113,113,118,110,101,119,98,95,94,87,117,125,97,133,117,48,139,115,91,102,120,149,91,108,95,115,108,97,95,124,85,96,100,102,94,134,114,107,105,100,78,102,93,104,83,99,77,86,104,84,91,139,101,127,124,139,102,102,94,101,96,92,109,115,103,111,97,158,102,92,113,93,94,106,46,133,102,126,128,114,114,94,110,85,98,90,94,135,91,116,105,97,101,92,119,106,101,103,104,111,121,121,107,107,95,111,105,127,158,109,116,93,87,102,101,88,97,89,85,121,132,132,92,83,97,117,120,129,92,86,137,209,121,93,107,98,81,86,141,98,123,100,106,106,79,116,106,83,88,103,98,85,100,130,98,90,96,98,109,99,110,110,119,123,91,91,88,108,115,126,94,114,96,92,124,27,112,135,104,114,122,130,107,126,101,106,106,96,95,104,95,113,106,100,105,100,98,96,87,97,102,87,87,95,97,117,102,87,87,97,118,92,168,103,82,113,103,119,103,97,92,22,108,89,24,119,123,131,91,104,92,108,90,108,89,92,109,23,120,78,130,75,80,123,93,93,102,102,119,93,104,83,99,100,94,104,176,137,86,125,91,92,102,110,111,92,103,112,122,95,119,102,128,97,103,105,118,110,98,93,139,150,143,92,147,78,74,74,83,72,80,75,75,128,81,121,100,97,91,93,88,110,144,135,120,88,123,94,112,99,111,119,117,99,98,98,85,145,145,108,82,77,115,106,113,82,87,146,99,104,106,106,108,96,172,124,137,110,112,127,101,112,112,90,93,108,93,93,93,140,133,115,112,200,99,93,105,92,140,109,91,103,102,107,96,96,102,108,133,101,124,118,181,98,93,88,118,113,115,112,97,97,93,167,87,109,110,100,110,113,106,105,130,90,90,90,98,117,110,95,116,96,101,88,93,124,102,122,122,126,118,111,100,86,120,134,93,97,105,116,117,91,119,87,108,89,123,127,119,153,106,134,71,101,133,123,138,118,110,90,111,137,100,86,114,116,99,121,96,109,101,115,93,100,110,110,100,89,150,90,108,85,95,118,153,153,103,76,93,99,99,107,131,98,112,141,119,46,46,101,97,97,110,109,99,92,131,96,118,104,102,127,122,125,92,86,90,126,112,86,84,117,91,109,105,95,81,120,96,114,131,154,106,99,129,111,114,112,120,120,119,100,92,104,118,137,121,116,117,109,95,126,88,195,77,112,121,117,95,106,146,103,128,83,96,107,94,101,107,135,104,128,109,106,139,117,129,94,103,86,98,113,106,117,78,107,113,154,116,97,97,89,88,109,115,93,107,113,89,97,90,95,86,118,116,119,97,96,112,96,113,101,99,102,112,93,84,104,112,8 ...

# %% [markdown]
# Film yang paling sering disajikan oleh netflix berkisar antara 90 hingga 104 menit, namun menariknya ada film yang durasinya di atas 3 jam.

# %% [markdown]
# Selain dalam bentuk histogram, kita juga dapat membuat distribusi numerik menggunakan fungsi kepadatan probabilitas (PDF) yang menggambarkan frekuensi relatif

# %%
import plotly.figure_factory as ff

fig = ff.create_distplot([data['duration_min'].values.flatten()],
                         group_labels = ['duration'], colors = ['#b20710'], show_hist = False)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="3df49943-903a-474a-9788-664431cb7d43" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("3df49943-903a-474a-9788-664431cb7d43")) {                    Plotly.newPlot(                        "3df49943-903a-474a-9788-664431cb7d43",                        [{"legendgroup":"duration","marker":{"color":"#b20710"},"mode":"lines","name":"duration","showlegend":true,"x":[22.0,22.414,22.828,23.242,23.656,24.07,24.484,24.898,25.312,25.726,26.14,26.554000000000002,26.968,27.381999999999998,27.796,28.21,28.624,29.038,29.451999999999998,29.866,30.28,30.694000000000003,31.108,31.522,31.936,32.35,32.763999999999996,33.178,33.592,34.006,34.42,34.834,35.248,35.662,36.076,36.49,36.903999999999996,37.318,37.732,38.146,38.56,38.974000000000004,39.388000000000005,39.802,40.216,40.629999999999995,41.044,41.458,41.872,42.286,42.7,43.114000000000004,43.528,43.942,44.356,44.769999999999996,45.184,45.598,46.012,46.426,46.84,47.254000000000005,47.668,48.082,48.495999999999995,48.91,49.324,49.738,50.152,50.566,50.980000000000004,51.394,51.808,52.222,52.635999999999996,53.05,53.464,53.878,54.292,54.706,55.12,55.534,55.948,56.362,56.776,57.19,57.604,58.018,58.432,58.846,59.26,59.674,60.088,60.502,60.916,61.33,61.744,62.158,62.572,62.986,63.4,63.814,64.22800000000001,64.642,65.056,65.47,65.884,66.298,66.712,67.126,67.53999999999999,67.95400000000001,68.368,68.782,69.196,69.61,70.024,70.438,70.852,71.26599999999999,71.68,72.094,72.50800000000001,72.922,73.336,73.75,74.164,74.578,74.99199999999999,75.406,75.82,76.23400000000001,76.648,77.062,77.476,77.89,78.304,78.718,79.132,79.54599999999999,79.96000000000001,80.374,80.788,81.202,81.616,82.03,82.444,82.858,83.27199999999999,83.686,84.1,84.51400000000001,84.928,85.342,85.756,86.17,86.584,86.998,87.412,87.826,88.24,88.654,89.068,89.482,89.896,90.31,90.724,91.138,91.552,91.966,92.38,92.794,93.208,93.622,94.036,94.45,94.864,95.278,95.692,96.106,96.52,96.934,97.348,97.762,98.176,98.59,99.004,99.418,99.832,100.246,100.66,101.074,101.488,101.902,102.316,102.73,103.144,103.558,103.972,104.386,104.8,105.214,105.628,106.042,106.456,106.87,107.284,107.698,108.112,108.526,108.94,109.354,109.768,110.182,110.596,111.01,111.424,111.838,112.252,112.666,113.08,113.494,113.908,114.322,114.736,115.15,115.564,115.978,116.392,116.806,117.22,117.634,118.048,118.462,118.876,119.29,119.704,120.118,120.532,120.946,121.36,121.774,122.188,122.602,123.016,123.43,123.844,124.258,124.672,125.086,125.5,125.914,126.328,126.742,127.156,127.57,127.984,128.398,128.812,129.226,129.64,130.054,130.46800000000002,130.882,131.296,131.70999999999998,132.124,132.538,132.952,133.36599999999999,133.78,134.19400000000002,134.608,135.022,135.436,135.85,136.264,136.678,137.09199999999998,137.506,137.92000000000002,138.334,138.748,139.162,139.576,139.99,140.404,140.81799999999998,141.232,141.64600000000002,142.06,142.474,142.888,143.30200000000002,143.716,144.13,144.54399999999998,144.958,145.372,145.786,146.2,146.614,147.02800000000002,147.442,147.856,148.26999999999998,148.684,149.098,149.512,149.926,150.34,150.754,151.168,151.582,151.996,152.41,152.824,153.238,153.652,154.066,154.48,154.894,155.308,155.722,156.136,156.55,156.964,157.378,157.792,158.206,158.62,159.034,159.448,159.862,160.276,160.69,161.104,161.518,161.932,162.346,162.76,163.174,163.588,164.002,164.416,164.83,165.244,165.658,166.072,166.486,166.9,167.314,167.728,168.142,168.556,168.97,169.384,169.798,170.212,170.626,171.04,171.454,171.868,172.282,172.696,173.11,173.524,173.938,174.352,174.766,175.18,175.594,176.008,176.422,176.836,177.25,177.664,178.078,178.492,178.906,179.32,179.734,180.148,180.562,180.976,181.39,181.804,182.218,182.632,183.046,183.46,183.874,184.288,184.702,185.116, ...

# %% [markdown]
# Dari grafik di atas menggambarkan bahwa durasi film yang paling sering disajikan (90 - 104 menit) berada di 2.5% dari total jumlah data. Artinya sebaran durasi film ini masih sangat menyebar karena titik puncak yang tidak terlalu mencolok dari jumlah dataset

# %% [markdown]
# ## Movie Financial Performance
#
# Selanjutnya kita akan menganalisis distribusi tentang revenue, budget_x, dan profit menggunakan boxplot

# %%
from plotly.subplots import make_subplots

# Chart 1
fig1 = px.box(data, y="revenue", hover_name="title", hover_data=["genre", "date_added", "budget_x", "profit"])

# Chart 2
fig2 = px.box(data, y="budget_x", hover_name="title", hover_data=["genre", "date_added", "revenue", "profit"])

# Chart 3
fig3 = px.box(data, y="profit", hover_name="title", hover_data=["genre", "date_added", "budget_x", "revenue"])

# Gabungkan dalam satu layout subplot
fig = make_subplots(rows=1, cols=3, subplot_titles=['Revenue', 'Budget', 'Profit'])

# Tambahkan chart 1 ke subplot
fig.add_trace(fig1['data'][0], row=1, col=1)

# Tambahkan chart 2 ke subplot
fig.add_trace(fig2['data'][0], row=1, col=2)

# Tambahkan chart 3 ke subplot
fig.add_trace(fig3['data'][0], row=1, col=3)

# Atur layout subplot
fig.update_layout(title_text='Combined Box Plots', showlegend=False)

# Tampilkan chart
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="0dd2a4e2-5d3b-48d7-a8d0-f559c59f2e11" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("0dd2a4e2-5d3b-48d7-a8d0-f559c59f2e11")) {                    Plotly.newPlot(                        "0dd2a4e2-5d3b-48d7-a8d0-f559c59f2e11",                        [{"alignmentgroup":"True","customdata":[[["Comedies","Dramas"],"2021-09-24T00:00:00",100000000.0,269861963.8],[["Comedies"],"2021-09-20T00:00:00",75000000.0,197222420.0],[["Horror Movies","Sci-Fi & Fantasy"],"2021-09-19T00:00:00",3500000.0,24204111.0],[["Thrillers"],"2021-09-19T00:00:00",40000000.0,-23659233.0],[["Action & Adventure","Classic Movies","Dramas"],"2021-09-16T00:00:00",12000000.0,470947378.0],[["Dramas","Horror Movies","Thrillers"],"2021-09-16T00:00:00",20000000.0,188900376.0],[["Action & Adventure","Horror Movies","Thrillers"],"2021-09-16T00:00:00",23000000.0,28881013.0],[["Action & Adventure"],"2021-09-16T00:00:00",85000000.0,122884401.0],[["Dramas","Thrillers"],"2021-09-16T00:00:00",45000000.0,59505352.0],[["Action & Adventure"],"2021-09-10T00:00:00",37800000.0,600919244.4],[["Sci-Fi & Fantasy","Thrillers"],"2021-09-09T00:00:00",6000000.0,27100520.4],[["Children & Family Movies","Comedies"],"2021-09-01T00:00:00",19000000.0,51112484.0],[["Action & Adventure","Sci-Fi & Fantasy"],"2021-09-01T00:00:00",49000000.0,56002056.0],[["Action & Adventure","Dramas"],"2021-09-01T00:00:00",62000000.0,145500000.0],[["Action & Adventure"],"2021-09-01T00:00:00",65000000.0,190000000.0],[["Dramas","Romantic Movies"],"2021-09-01T00:00:00",80000000.0,85173909.0],[["Action & Adventure","Comedies"],"2021-09-01T00:00:00",25000000.0,14393111.0],[["Classic Movies","Comedies","Dramas"],"2021-09-01T00:00:00",6000000.0,20051502.0],[["Dramas","International Movies","Thrillers"],"2021-09-01T00:00:00",92400000.0,688930534.6],[["Action & Adventure"],"2021-09-01T00:00:00",65000000.0,-65000000.0],[["Dramas"],"2021-09-01T00:00:00",21000000.0,22632609.0],[["Action & Adventure","Sci-Fi & Fantasy"],"2021-09-01T00:00:00",200000000.0,19535492.0],[["Comedies","Cult Movies"],"2021-09-01T00:00:00",2500000.0,23886000.0],[["Action & Adventure","Children & Family Movies","Cult Movies"],"2021-09-01T00:00:00",25000000.0,-12270083.0],[["Comedies","Dramas","Romantic Movies"],"2021-09-01T00:00:00",30000000.0,52148538.0],[["Sci-Fi & Fantasy","Thrillers"],"2021-09-01T00:00:00",53740900.0,-53725325.0],[["Comedies","Cult Movies","Sci-Fi & Fantasy"],"2021-09-01T00:00:00",80000000.0,21371017.0],[["Dramas"],"2021-09-01T00:00:00",12000000.0,-1883184.0],[["Action & Adventure","Comedies"],"2021-09-01T00:00:00",68000000.0,-34537989.0],[["Classic Movies","Dramas"],"2021-09-01T00:00:00",30000000.0,-24423471.0],[["Children & Family Movies","Comedies"],"2021-09-01T00:00:00",39120168.6,-30420168.6],[["Action & Adventure","Children & Family Movies","Comedies"],"2021-09-01T00:00:00",70000000.0,-56403089.0],[["Comedies","Music & Musicals"],"2021-09-01T00:00:00",20000000.0,111944672.0],[["Action & Adventure","Dramas"],"2021-09-01T00:00:00",75000000.0,10632458.0],[["Dramas","Romantic Movies"],"2021-09-01T00:00:00",4500000.0,43423795.0],[["Action & Adventure","Comedies"],"2021-09-01T00:00:00",12000000.0,67817937.0],[["Action & Adventure","Classic Movies"],"2021-09-01T00:00:00",6000000.0,22900000.0],[["Action & Adventure","Comedies"],"2021-09-01T00:00:00",44000000.0,-31657368.0],[["Comedies","Romantic Movies"],"2021-09-01T00:00:00",55000000.0,218814019.0],[["Comedies"],"2021-09-01T00:00:00",27500000.0,16107627.0],[["Action & Adventure","Classic Movies"],"2021-08-31T00:00:00",40000000.0,136997168.0],[["Dramas","Independent Movies"],"2021-08-28T00:00:00",11000000.0,33984979.0],[["Action & Adventure"],"2021-08-25T00:00:00",15000000.0,19 ...

# %% [markdown]
# - Batas atas outlier untuk pendapatan film-film yang tersedia di netflix adalah 727 Juta USD
# - Batas atas outlier untuk budget film-film yang tersedia di netflix adalah 190 Juta USD
# - Batas atas outlier untuk profit film-film yang tersedia di netflix adalah 527 Juta USD

# %% [markdown]
# ## Analysis of Relationship
#
# Kita akan mencoba menjawab apa yang menyebabkan suatu film mendapatkan score IMDb bagus berdasarkan fitur-fitur pada data menggunakan matriks korelasi

# %% [markdown]
# Kita pilih dahulu kolom-kolom numerik pada dataset yang kita punya

# %%
data_numeric = data.select_dtypes(include='number')

data_numeric
# Out:
#      release_year     budget_x      revenue  score  year_added  month_added  \
# 0            2021  100000000.0  369861963.8     71        2021            9
# 1            2010   75000000.0  272222420.0     64        2021            9
# 2            2013    3500000.0   27704111.0     63        2021            9
# 3            2013   40000000.0   16340767.0     57        2021            9
# 4            1975   12000000.0  482947378.0     77        2021            9
# ..            ...          ...          ...    ...         ...          ...
# 939          2002   70000000.0  267200000.0     59        2019            1
# 940          2005   60000000.0   71073932.0     50        2019            1
# 941          2008   90000000.0  204313400.0     57        2019            9
# 942          2011   12000000.0   22750356.0     58        2019           11
# 943          2006   35000000.0   12506188.0     54        2020            1
#
#      release_day_gap  duration_min       profit
# 0                  7           104  269861963.8
# 1               4106           103  197222420.0
# 2               3112            97   24204111.0
# 3               2908           106  -23659233.0
# 4              16731           124  470947378.0
# ..               ...           ...          ...
# 939             5934           124  197200000.0
# 940             4996           101   11073932.0
# 941             4034           113  114313400.0
# 942             2862            94   10750356.0
# 943             4901            88  -22493812.0
#
# [944 rows x 9 columns]

# %% [markdown]
# Buat dataframe matriks korelasi berdasarkan dataframe numerik

# %%
corr_data = data_numeric.corr()

corr_data
# Out:
#                  release_year  budget_x   revenue     score  year_added  \
# release_year         1.000000  0.238910  0.192888 -0.187004   -0.139645
# budget_x             0.238910  1.000000  0.707480 -0.051861   -0.063959
# revenue              0.192888  0.707480  1.000000  0.092861   -0.035776
# score               -0.187004 -0.051861  0.092861  1.000000    0.084197
# year_added          -0.139645 -0.063959 -0.035776  0.084197    1.000000
# month_added         -0.002076  0.023482 -0.002131 -0.030292   -0.219149
# release_day_gap     -0.992808 -0.236591 -0.188253  0.188061    0.247934
# duration_min        -0.255130  0.039478  0.017104  0.381415    0.129525
# profit               0.164271  0.571614  0.984296  0.120765   -0.025561
#
#                  month_added  release_day_gap  duration_min    profit
# release_year       -0.002076        -0.992808     -0.255130  0.164271
# budget_x            0.023482        -0.236591      0.039478  0.571614
# revenue            -0.002131        -0.188253      0.017104  0.984296
# score              -0.030292         0.188061      0.381415  0.120765
# year_added         -0.219149         0.247934      0.129525 -0.025561
# month_added         1.000000         0.000038      0.003594 -0.008339
# release_day_gap     0.000038         1.000000      0.262780 -0.159469
# duration_min        0.003594         0.262780      1.000000  0.009998
# profit             -0.008339        -0.159469      0.009998  1.000000

# %%
corr_data = pd.DataFrame(corr_data).reset_index().rename(columns={'index': 'feature'})

corr_data
# Out:
#            feature  release_year  budget_x   revenue     score  year_added  \
# 0     release_year      1.000000  0.238910  0.192888 -0.187004   -0.139645
# 1         budget_x      0.238910  1.000000  0.707480 -0.051861   -0.063959
# 2          revenue      0.192888  0.707480  1.000000  0.092861   -0.035776
# 3            score     -0.187004 -0.051861  0.092861  1.000000    0.084197
# 4       year_added     -0.139645 -0.063959 -0.035776  0.084197    1.000000
# 5      month_added     -0.002076  0.023482 -0.002131 -0.030292   -0.219149
# 6  release_day_gap     -0.992808 -0.236591 -0.188253  0.188061    0.247934
# 7     duration_min     -0.255130  0.039478  0.017104  0.381415    0.129525
# 8           profit      0.164271  0.571614  0.984296  0.120765   -0.025561
#
#    month_added  release_day_gap  duration_min    profit
# 0    -0.002076        -0.992808     -0.255130  0.164271
# 1     0.023482        -0.236591      0.039478  0.571614
# 2    -0.002131        -0.188253      0.017104  0.984296
# 3    -0.030292         0.188061      0.381415  0.120765
# 4    -0.219149         0.247934      0.129525 -0.025561
# 5     1.000000         0.000038      0.003594 -0.008339
# 6     0.000038         1.000000      0.262780 -0.159469
# 7     0.003594         0.262780      1.000000  0.009998
# 8    -0.008339        -0.159469      0.009998  1.000000

# %% [markdown]
# Simpan hasil dataframe correlation matrix ke google drive

# %%
from google.colab import drive

# saving the excel
corr_data.to_excel("corr_data_netflix_imdb.xlsx", index=False)
# !cp corr_data_netflix_imdb.xlsx "drive/My Drive/Dataset"

# %% [markdown]
# Kita buat heatmapnya menggunakan plotly

# %%
fig = px.imshow(corr_data, text_auto=True, aspect = 'auto')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="b476088a-439d-48d4-9a55-47b268936585" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("b476088a-439d-48d4-9a55-47b268936585")) {                    Plotly.newPlot(                        "b476088a-439d-48d4-9a55-47b268936585",                        [{"coloraxis":"coloraxis","name":"0","texttemplate":"%{z}","x":["feature","release_year","budget_x","revenue","score","year_added","month_added","release_day_gap","duration_min","profit"],"y":[0,1,2,3,4,5,6,7,8],"z":[["release_year",1.0,0.23890953041244942,0.19288818818938905,-0.18700395195988906,-0.1396447166679831,-0.002076042435762241,-0.992807510238919,-0.255129803739152,0.1642710662865526],["budget_x",0.23890953041244942,1.0,0.7074795171374709,-0.051860502287244384,-0.0639589758036074,0.023481714318125096,-0.23659087504130621,0.03947776073669161,0.5716144121378248],["revenue",0.19288818818938905,0.7074795171374709,1.0,0.09286082994381106,-0.03577573247235371,-0.0021309209120834,-0.18825320193883152,0.01710416879914911,0.9842964225376117],["score",-0.18700395195988906,-0.051860502287244384,0.09286082994381106,1.0,0.08419732935220442,-0.03029204741125577,0.18806118687692627,0.38141517694604343,0.12076538713758912],["year_added",-0.1396447166679831,-0.0639589758036074,-0.03577573247235371,0.08419732935220442,1.0,-0.21914879705094756,0.247934047931759,0.12952535890253766,-0.025560577683065386],["month_added",-0.002076042435762241,0.023481714318125096,-0.0021309209120834,-0.03029204741125577,-0.21914879705094756,1.0,3.778594384441975e-05,0.003594262974651125,-0.008339126709859658],["release_day_gap",-0.992807510238919,-0.23659087504130621,-0.18825320193883152,0.18806118687692627,0.247934047931759,3.778594384441975e-05,1.0,0.26277962041409175,-0.15946895766081465],["duration_min",-0.255129803739152,0.03947776073669161,0.01710416879914911,0.38141517694604343,0.12952535890253766,0.003594262974651125,0.26277962041409175,1.0,0.009997540020974539],["profit",0.1642710662865526,0.5716144121378248,0.9842964225376117,0.12076538713758912,-0.025560577683065386,-0.008339126709859658,-0.15946895766081465,0.009997540020974539,1.0]],"type":"heatmap","xaxis":"x","yaxis":"y","hovertemplate":"x: %{x}\u003cbr\u003ey: %{y}\u003cbr\u003ecolor: %{z}\u003cextra\u003e\u003c\u002fextra\u003e"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333 ...

# %% [markdown]
# Kita pangkas cell yang redundan dan korelasi ke kolom itu sendiri (self-correlation) sehingga tidak terlalu banyak informasi pada tabel

# %%
corr_data_viz = corr_data.mask(np.triu(np.ones_like(corr_data, dtype=bool))).dropna(how='all').dropna('columns', how='all')

fig = px.imshow(corr_data_viz, text_auto=True, aspect = 'auto')

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="df4ce068-91c4-421b-9a7a-284a545b237d" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("df4ce068-91c4-421b-9a7a-284a545b237d")) {                    Plotly.newPlot(                        "df4ce068-91c4-421b-9a7a-284a545b237d",                        [{"coloraxis":"coloraxis","name":"0","texttemplate":"%{z}","x":["feature","release_year","budget_x","revenue","score","year_added","month_added","release_day_gap"],"y":[1,2,3,4,5,6,7,8],"z":[["budget_x",null,null,null,null,null,null,null],["revenue",0.19288818818938905,null,null,null,null,null,null],["score",-0.18700395195988906,-0.051860502287244384,null,null,null,null,null],["year_added",-0.1396447166679831,-0.0639589758036074,-0.03577573247235371,null,null,null,null],["month_added",-0.002076042435762241,0.023481714318125096,-0.0021309209120834,-0.03029204741125577,null,null,null],["release_day_gap",-0.992807510238919,-0.23659087504130621,-0.18825320193883152,0.18806118687692627,0.247934047931759,null,null],["duration_min",-0.255129803739152,0.03947776073669161,0.01710416879914911,0.38141517694604343,0.12952535890253766,0.003594262974651125,null],["profit",0.1642710662865526,0.5716144121378248,0.9842964225376117,0.12076538713758912,-0.025560577683065386,-0.008339126709859658,-0.15946895766081465]],"type":"heatmap","xaxis":"x","yaxis":"y","hovertemplate":"x: %{x}\u003cbr\u003ey: %{y}\u003cbr\u003ecolor: %{z}\u003cextra\u003e\u003c\u002fextra\u003e"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e" ...

# %% [markdown]
# - Release Year dan Release Day Gap:
# Terdapat korelasi negatif yang sangat kuat antara "Release Year" dan "Release Day Gap" (sebaliknya). Ini berarti semakin baru rilisnya film, semakin kecil jarak hari antara tanggal rilis dan tanggal penambahan ke Netflix.
#
# - Budget dan Revenue:
# Terdapat korelasi positif yang kuat antara "Budget" dan "Revenue". Ini menunjukkan bahwa film dengan anggaran yang lebih besar cenderung menghasilkan pendapatan yang lebih tinggi.
#
# - Score dan Duration:
# Ada korelasi positif yang kuat antara "Score" (peringkat) dan "Duration" (durasi film). Hal ini mungkin menunjukkan bahwa film dengan peringkat yang lebih tinggi cenderung memiliki durasi yang lebih panjang.
#
# - Profit dan Revenue:
# Ada korelasi positif yang sangat kuat antara "Profit" dan "Revenue". Ini bermakna bahwa film dengan pendapatan yang lebih tinggi cenderung memiliki keuntungan yang lebih besar.
#
# - Release Year dan Duration:
# Terdapat korelasi negatif yang cukup kuat antara "Release Year" dan "Duration". Ini bisa menunjukkan bahwa film yang lebih baru cenderung memiliki durasi yang lebih pendek.
#
# - Year Added dan Release Day Gap:
# Terdapat korelasi positif yang cukup kuat antara "Year Added" dan "Release Day Gap". Ini bisa menunjukkan bahwa semakin baru film ditambahkan ke Netflix, semakin kecil jarak hari antara tanggal rilis dan tanggal penambahan ke Netflix.
#
# - Profit dan Budget:
# Ada korelasi positif yang kuat antara "Profit" dan "Budget". Ini menunjukkan bahwa film dengan anggaran yang lebih besar cenderung memiliki keuntungan yang lebih besar.
#
# - Score dan Profit:
# Korelasi antara "Score" dan "Profit" tergolong rendah. Ini berarti tidak ada hubungan yang jelas antara peringkat film dan keuntungan yang dihasilkan.
#
# - Score dan Revenue:
# Korelasi antara "Score" dan "Revenue" tergolong rendah. Ini berarti tidak ada hubungan yang jelas antara peringkat film dan keuntungan yang dihasilkan.

# %% [markdown]
# # Conclusion
#
# Berdasarkan data yang kita olah dan analisis, disimpulkan bahwa:
#
# - Avengers: Infinity War adalah film yang paling ambisius, efektif, dan menguntukan
# - Drama adalah jenis film terbanyak yang tersedia di netflix dan disusul oleh film komedi dan film aksi petualangan
# - Netflix memiliki target penonton terbesar pada orang-orang dewasa, yang dimana sejalan dengan model bisnis netflix yang dimana tidak murah untuk mendaftar penggunaan layanan netflix
# - Meskipun Amerika memiliki nilai skor IMDb tertinggi, akan tetapi jika di rata-rata ada beberapa negara yang memiliki skor rata-rata IMDb lebih tinggi dari Hollywood atau Amerika, akan tetapi rata-rata skor ini bergantung juga dengan jumlah film di dalamnya. Oleh karena itu kita perlu melihat distribusi jumlah film di setiap negara
# - Dari area chart ini kita dapat melihat bahwa film yang paling laku itu ketika dirilis ke netflix pada bulan Januari, bukan di bulan-bulan musim panas Amerika (Juli - September)
# - durasi film yang paling sering disajikan (90 - 104 menit) berada di 2.5% dari total jumlah data. Artinya sebaran durasi film ini masih sangat menyebar karena titik puncak yang tidak terlalu mencolok dari jumlah dataset
# - Batas atas outlier untuk pendapatan, budget, dan proft film-film yang tersedia di netflix adalah 727 Juta USD, 190 Juta USD, dan 527 Juta USD
# - Menariknya Score IMDb ini tidak memiliki hubungan linier dengan pendapatan atau keuntungan dari suatu film

# %% [markdown]
# # Homework
#
# Buat analisis tambahan berdasarkan data di atas, gunakan chart sesuai dengan analisis yang dibutuhkan menggunakan Python & Google Data Studio (looker studio)
#
# 1.   Bagaimana tren target usia dari tahun ke tahun?
# 2.   Bagaimana tren IMDb score dari tahun ke tahun berdasarkan target usia?
# 3.   Siapakah top 10 sutradara yang filmnya paling banyak di netflix?
# 4.   Buatkan wordcloud sutradara berdasarkan budget film
# 5.   Apakah ada artis yang sering bekerja sama dengan sutradara yang sama di lebih dari 1 film?
# 6.   Buatkan peta negara yang nilainya berdasarkan bahasa asli film?
